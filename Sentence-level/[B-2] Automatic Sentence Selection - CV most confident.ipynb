# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold
from textblob import TextBlob

# %%
def open_pickle(path):
    with open(path, 'rb') as f:
        X = pickle.load(f)
    return X

# %% [markdown]
# ### Load Data

# %%
#Load dataset of [whole corpus]

X_train_original = open_pickle('../data/imdb/imdb_original_preprocessed_xtrain.pickle')
X_test_original = open_pickle('../data/imdb/imdb_original_preprocessed_xtest.pickle')
y_train_original = open_pickle('../data/imdb/imdb_original_preprocessed_ytrain.pickle')
y_test_original = open_pickle('../data/imdb/imdb_original_preprocessed_ytest.pickle')

#Load dataset of sentence [+/-]

X_train_np_sentence = open_pickle('../data/imdb-sentence/imdb_sentence_np_xtrain.pickle')
X_test_np_sentence = open_pickle('../data/imdb-sentence/imdb_sentence_np_xtest.pickle')
y_train_np_sentence = open_pickle('../data/imdb-sentence/imdb_sentence_np_ytrain.pickle')
y_test_np_sentence = open_pickle('../data/imdb-sentence/imdb_sentence_np_ytest.pickle')

# %% [markdown]
# ### Preprocessing

# %%
# Count Vectorizer on rel,unrel dataset
# Question : Why rel/unrel? Because it trained as the first step? 
# Any advantages on more vocabulary?

token = r"(?u)\b[\w\'/]+\b"
tf_vectorizer = CountVectorizer(lowercase=True, max_df=1.0, min_df=5, binary=True, token_pattern=token)
tf_vectorizer.set_params(ngram_range=(1,1))

# whole imdb corpus
X_train_original_bow = tf_vectorizer.fit_transform(X_train_original)
X_test_original_bow = tf_vectorizer.transform(X_test_original)

# positive/negative sentence
X_train_np_bow = tf_vectorizer.transform(X_train_np_sentence)
X_test_np_bow = tf_vectorizer.transform(X_test_np_sentence) 

words = tf_vectorizer.get_feature_names()
words = np.array(words)

# %%
# Initial variable
random_state = 42
C = 1

# using whole corpus
clf_i = LogisticRegression(random_state=random_state, C=C)
clf_i.fit(X_train_original_bow, y_train_original)

# using the [+/-] sentence

clf_j = LogisticRegression(random_state=random_state, C=C)
clf_j.fit(X_train_np_bow, y_train_np_sentence)
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ### Approach
#
# Extraction

# %%
i=4
sentences = TextBlob(X_test_original[i]).raw_sentences

# %%
# for j in x[chosen_sentence_index].indices:
#     print("%s\t%0.3f" %(terms[j], weights[j]))

# %%
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# %%
chosen_sentences = {}

# %%
for train_index, test_index in kf.split(X_train_original_bow):
    clf = LogisticRegression(penalty='l1', C=1)
    clf.fit(X_train_original_bow[train_index], y_train_original[train_index])
    print(clf.score(X_train_original_bow[train_index], y_train_original[train_index]))
    print(clf.score(X_train_original_bow[test_index], y_train_original[test_index]))
    for i in test_index:
        sentences = TextBlob(X_train_original[i]).raw_sentences
        x = tf_vectorizer.transform(sentences)
        probs = clf.predict_proba(x)
        chosen_sentence_index = np.argmax(probs, axis=0)[y_train_original[i]]
        chosen_sentences[i] = sentences[chosen_sentence_index]
    #    sentences = X_train[i]
    #    for sent in sentences:
    #        v = vect.transform()
# Out:
# 0.9826593063722548
# 0.8707703383729302
# 0.9852402951940962
# 0.8676347053882155
# 0.9842803143937121
# 0.8712348493939758

# %%
chosen_sentences
# Out:
# {0: 'whee.a step up from part 4, but not much of one.',
#  3: "we have high-tech international terrorists/criminal who bicker like pre-school kid, stallone's man-of-steel-type resilience toward ice-cold weather, dialog so dumb that it is sometimes almost hilarious, and so on.",
#  6: '1st watched 12/7/2002 - 3/10(dir-steve purcell): typical mary kate and ashley fare with a few more kiss.',
#  17: 'he is played by david oyelowo, who is illiant at the part, coming across as a totally sympathetic person, although his only activity for five hour are loving and grieving, which he does superbly, so that one wants to comfort him, as he is so obviously a nice guy.',
#  19: 'wb had to mess this up with some tripe batman of the future.',
#  29: "the family continues to stay in the haunted house as thing get worse and worse and no mention of the monk is made until nearly the very end when he turns up again to do what he should have done an hour earlier--try to drive the spirit out of the house, although by this time it is difficult for the viewer to care.there are some (probably) unintentional campy laughs in seeing the american actor at the end become possessed by the japanese spirit and suddenly start doing bad martial art, i say probably because the scene is more than a little reminiscent of the chainsaw duel from the same director's motel hell which was more obviously meant to be amusing, but on the whole this is a forgettable dud.",
#  30: 'it gets into the mind of person with eating disorder, and shows the complication and pain, in a very realistic way, and i loved that.',
#  31: 'the character are very realistic most of the time, sappy sometime, but quite believable.',
#  34: 'but on the other hand it is nothing more then a cheap action movie (like there are so so many out there) with an average set of actor and a vinnie jone who is managing to not totally ruin what is left of his reputation by doing what he always does.so all in all i .. just ... can not recommend it.1 for vinnie and 2 for the editing.',
#  35: "fessenden successfully continues george romero's tradition of using the genre as parable and as a discussion forum while still keeping us creeped out.",
#  41: '"pandemonium" is a horror movie spoof that comes off more stupid than funny.',
#  42: "while the story is good on its own, i think what really makes this movie fun to watch is michael curtiz' fantastically imaginative direction.",
#  44: 'the entire film was poorly dubbed and made watching mouth while listening to their voice very irritating.',
#  46: 'the tale of homer hickham and his dream of creating a rocket seem so simple at first, especially when the film is set in a mining town, where the future is as clear cut as the lump of coal in the mine.',
#  47: 'crawford and dennis christopher( jake sidekick) are a good team,although you do wonder why they both put up with each other.however ,together both crawford and christopher portray a team that is just so much fun that, if you can get over yourself for a moment, you may find yourself acting like a kid again at the situation and the inherent suspense they provide.the delicious karen kopins does a great job as the damsel in distress that is more concerned about the motive of her rescuer then her tormentor.i have yet to find a movie that is as much fun without getting preachy,or bogging down the movie by trying too hard.',
#  49: 'and i have seen a lot of movie.',
#  50: "so apparently, jeffrey's son was dying of cancer which prompted our mad doctor to start experimenting on his progeny.",
#  52: 'reid perform as if she has either forgotten her acting lesson, been severely hit on the head and made to forget her acting lesson, or has one of the worst director in the history of film.',
#  54: "sure, this film has some problem, notably talia shire's delirious hamwork as the overwrought nun, 1950s-style attire and all.",
#  57: "i almost gave it an 8/10, but let's not get crazy.",
#  59: 'a solid and satisfying winner.',
#  62: '),anyway all of the review on here will tell you more detail if you need them buy girl, take it from me, get your hubby/boyfriend in front of the television on a saturday night and you will both laugh and cry together.',
#  69: 'if he saw lil\' kim, he might say, "alright!',
#  72: 'dear god i do not know where to start why this movie sucked too much.',
#  75: 'since i do not want to spoil (not that there was anything to spoil) i shall let your imagination figure out the "zany" (and i use that word lightly) antic that follow.i had to fight to stay awake through this snore a minute sleeper of a film, and i would like to say that if you are venturing to the movie store and are thinking about being adventurous, please do not, it is a waste of the film it was printed on.then again i could be wrong...',
#  83: 'the action is fantastic, the story is tense and entertaining, and the set design is truely memorable.',
#  87: 'robert downey jr. does such justice to the role of "louis jeffry" reincarnated and the storyline (although far-fetched) is romantic and makes one believe in happy ending!',
#  88: 'caring for these forgotten baby turns out to be quite a chore, leaving the little nipper with no choice but to come up with some ingenious solution to the baby-sitting problem...spanky is in his glory in this hilarious little film, arguably his best.',
#  90: 'not more to say except that this is a great movie!my rating: story 8.5/10, acting 7.5/10, animals+fx 8.5/10, cinematography 8/10.my overall rating: 8/10 - big family movie and very worth watching!',
#  91: 'i am giving this pretentious piece of garbage a 1 simply because i do not believe there is a worse movie in the world.i hate this movie, i hate the acting, dialog, setting, writing and directing.',
#  99: 'my son, who turns 21 this year, is surprised wei wei was so beautiful then.',
#  101: 'when you watch it, you feel for him, you feel his frustration, the injustice against him, and you cheer him on when he goes for vengeance, even though he frightens you a little with his original fury.',
#  102: 'having said that i now have a greater respect for firefighter and i realize becoming a firefighter is a life altering job.',
#  103: 'think of the potential this plot would have had without the poorly written character, without the bad writing, and without all that unnecessary and unfunny comedy.',
#  109: 'i love some of the film out now, but rarely are there any that i would put on a "100 best" list.. "hustle and flow" was great, so was "fargo", and "oh, brother, where art thou," from a line in sullivan\'s travel; another fine film from the forty!',
#  115: 'there is no real idea in it... nothing to consider except being the mother of the devil.the dakota is barely exploited for it eerie potential.',
#  116: 'i am not sure he could make a movie any worse than this.in his defense the major problem with this film seem to occur in post-production.',
#  119: 'everything try to be too comic and goofy, by using intentional bad acting, an overuse of pointless death, and doing the same thing...over and over.',
#  121: 'however, i sat patiently through the entire film and found it to be a dull, dis-interesting, slow pace, twisted, confusing saga which if it had a theme or plot must have been left on some dark back room self.',
#  123: "yes, it is flawed - especially if you are into hollywood film that demand a lot of effect, a purely entertaining or fantasy story or plot, and you can not actually think for yourself.roeg's film are for the intelligent film-goer, and insignificance is a perfect example.the characterization are illiant, the story is excellent, but, like all nic roeg's film - it has you thinking on every level about aspect of reality that would never have dawned on you before.",
#  127: 'the latter was about building your dream house - in the late 1980. although the two film have their momant, both are not as good as blanding, which was based on an autobiographical novel of the same name.jim blanding and his wife muriel (cary grant and myrna loy) are noticing the tight corner of their apartmant, which they share with their two daughter joan and betsy (sharyn moffett and connie marshall).',
#  128: 'we are predator ourself.',
#  129: 'bad special effect, a weak storyline, ridiculous amount of blood and gore, annoying and pointless character, all that you can expect.',
#  133: 'i have to digress somewhat though because i have seen stephanie sanchez in several play and she is awesome.',
#  134: 'the mattress sequel came closest, but even they never reached such depth of utterly putrid nauseating appallingness that this bilge did.since wasting 90 minute of my life witnessing this plague on human kind i am now unable to even look at any book by jame hawes without feeling angry.',
#  137: 'even for a sequel.8/10quality: 9/10 entertainment: 7/10 replayable:7/10',
#  139: "this whole movie is screwed up.they could not get the species of animal for this movie right.whats an orangutang doing hanging around those chimpanzee?he must have wandered off the set of a much better film.the group of cannibal tribe's man look caucasin.why?and why was bo and her dad painted,if they were going to be eaten later?it was probably just a lame excuse to show her east and curves again.her dad while hunting, approach and act stupidly around a bull elephant while standing too close to it.any real african bull elephant that was not from the circus,would've stomped this moron's butt.any smart hunter would've started shooting the minute he saw it.and i can not help but wonder if the camera was on lsd,because it kept showing various scene that went in slow motion, for no good reason.it did not make good sense at all.the boa constrictor that tarzan wrestled with in the water,looks like one of those 12 ft rubber snake you can buy at a local spencer gifts.tarzan was strangly speechless in this film,maybe from bo flashing herself so much.i am sorry,but this is a rip off of a classic black and white tarzan movie,with a similar but better story.not to mantion plotting .there is one scene in that i saw that everyone forgot to mantion.",
#  140: "what else can you say about this movie,except that it is plain awful.tina louise and adam west are the reason why to see this,but,that is it,but their talent are wasted in this junk.i think that they used a double in some of adam's scene,like when he is running because you can not see his face.if adam was embarrassed in being in zombie nightmare,just think what he must've felt about appearing in this???",
#  146: 'i like the movie overall so i give it a...still a good 7/10 for me.',
#  147: 'the plot is kinda... eh.. the last half hour is alright the rest is boring and not funny =( i had my hope up, the trailer made it look funny but the pace of this movie is pretty slow and sadly not funny.',
#  150: 'watch this movie if you want to waste some time.',
#  167: 'frankly i am not sure what happens in this film which is full of very strange, very surreal image some of which parent might find disturbing, (ie.the cat slicing off part of a pig who is traveling with them and the frying it like bacon which all three eat).this is a very strange film that some have likened to hello kitty on acid, i think its more like hello kitty as done by dali.',
#  168: 'anyway, this is a good short that does not quite live up to some other tom and jerry cartoon, but it is still nice.7/10',
#  169: 'i was not even prepared for what i was about to watch.there was barely a shred of the original show still intact.here is a short list of just some of the con for this movie: *the humor is non-existent from the original series.',
#  175: 'i saw the description of the movie on tcm and only let it run because i like both peter ustinov and maggie smith, so i was delightfully surprised to find that i really liked the movie and found it quite exceptional.',
#  177: 'sorry to say but do not even bother you will waste time and money.boring!!',
#  180: '7/10 - otto seems content to follow the hawksian mould of what a noir is, rather than toy with the possibility of where noir can go.',
#  188: 'i am really not in a mood to review and criticize because there is simply nothing that i find worth remembering from this painful experience.',
#  194: 'it is raw, gritty, the character are real, the situation are believable and it does not shy away from the darker side of life confronted every day by cop and the criminal, victim, lawyer and other person in their various orbits.this show ran for 2 season and was discontinued because the show did not sell well overseas.',
#  196: 'brief crossing is not ief enough.',
#  199: 'it leads us to the worst issue in the bunch, the episodic format.',
#  200: "this looney tune episode is very funny, has reasonably good cartoon animation (marvin's animation is very well done) and the plot is well done.",
#  205: 'the music there was was annoying, and boring.',
#  208: 'its a shame how they do not better select who they pick.',
#  210: 'the cast is very fine, with cusack doing a nice job and tomei, joan cusack, ben kingsley, ackroyd and other backing him up in style.',
#  217: 'no joke, but stupid and boring laughing on repeated disgusting stuff.',
#  218: 'with all that she had to put up with in this movie -- the lame script, the endless makeup, getting baked in a cake at the end -- i hope they gave her an extremely-large paycheck.',
#  221: "it is all because she is the reincarnation of de sade's lost love.this typically sleazy harry alan tower production is redundant, seedy and pretty senseless, but the set, costume, cinematography and location work are all excellent and at least there is always something going on.score: 3/10",
#  222: 'the sound was particularly great and the setting was really creepy beautiful.',
#  224: "with the syfy channel's sure-fire recipe for creating b-movie creature feature and a cast that includes william forsythe and hunter tylo, how could it possibly go wrong?",
#  225: '8/10, but branagh and hbc get 10/10.',
#  230: 'none of the cast are able to generate interest in their shallow character, especially bill pullman, whose own inexplicably curious andy is impossible to believe.poor director harold becker is left trying to resurrect an impossibly dead project, and is unable to make entertainment from any of it.',
#  231: 'the movie is truly poignant, unique and uplifting.',
#  239: "perhaps i am too much of a child in the technological age: the movie was made, as it is now 2002, an official five year ago --after viewing fantasy epic such as lord of the ring, and science fiction feat like star war, as a whole it could not compare to other movie of similar line such as dinotopia or homer's the odyssey.my beef, basically, is that i could not relate --i am just about the same age of the child (a young adult), and have no trouble putting myself in the place of a middle-aged man if that is the character available.",
#  241: 'agreed there are poor and homeless in indium, but why is there no representation of educated person if not the successful ones.i totally hated the idea of the movie portraying patrick swayze as another mother teressa.',
#  245: 'basically, i like verhoeven film because in his film, i enjoy a illiant pscychosexual story that i have seen before in "basic instinct".it is really a wonderful thriller i enjoyed very much.so it is obviously for me to watch this another verhoeven movie.well, it is his previous direction before his block buster hit "basic instinct" and for that i was very much curious to watch that movie and yeah, the movie has fulfilled my hope and expectation.this movie "the fourth man" is a illiant pscychosexual drama which is a lit bit complex for some audience.',
#  247: 'huston\'s effort might be the worst of this rather bad lot(with the exception of "susie " maybe).john wayne perfectly fits in ford\'s world ,in huston\'s he is like a bull in a china shop.his japanese partner is totally bland.even the dramatic scene (cholera epidemic) do not save the movie from absolute boredom.only those utterly enamoured of huston\'s every work need to choose this ,among all his other great movie around.',
#  250: "the movie is wonderfully romantic in many sense of the word, the scenery is beautiful (as is polly walker), and the resolution in the movie are very satisfying.the movie takes a couple of liberty with the book, the biggest being with the arbuthnot/briggs/dester business, but i actually preferred the movie's version of this (it may be more sentimental, but i felt that it was more consistent with the tone of the story, and anyway i like sentiment when it is well done).an excellent movie, especially as a date movie during lousy weather.",
#  251: 'the violence is very shocking to watch even today, but again it is necessary to the plot to depict the world of a hustler.',
#  257: "this flick reminds me some really bad science-fiction movie from 50's and 60's.it is not scary or interesting,but it is dull,cheesy and stupid.special effect are laughable,all actor are ludicrous and the ending is simply awful.do not waste your money,rent or buy something better.i give it 3.5/10( i found this turkey quite amusing because of its stupidity).",
#  259: 'in her frustrated attempt to become the stereotypical movie star of that era, she kept repressing what would prove to be her ultimate gifts.i believe that rachel deftly captured the comedy, drama, wit, sadness, anger, passion, love, ambition, loyalty, sexiness, self absorption, childishness, and stoicism all rolled into one complex american icon.',
#  261: 'also, if you do decide to waste 2 hour of your life by watching this film, be sure to ing something to throw up in because the cinematography is simply someone running around with a hand-held camcorder and half the time you can not even see the main subject.',
#  263: 'soderburgh does an excellent job of setting the mood for the unraveling debacle that was che is bolivian adventure.',
#  265: 'i would have given it "0"/10, but the lowest mark was 1/10 and so i had to overestimate it by one mark.',
#  273: 'this seems like two film: one a dreary, pretentious lengthy saga about an ac-tor who is taken over by the part he plays; the other a illiant social comment about a middle aged divorce who is picked up by a waitress.',
#  274: "a sub-plot involving another couple taken hostage by baldwin's ex-partner was unbearable in the '72 film and play even worse here.",
#  278: 'the 10 that it really is.',
#  280: 'a guy like that never loses control, especially with a woman he raped before ... i guess this is supposed to show us how stupid he is.',
#  283: 'i give this show a 1/10, i would of liked to put a zero out of 10 but that was not an option.',
#  285: 'the film has won over 25 award at festival and i agree with the quote given to the film by variety, "certain to stir heart".',
#  286: 'do not waste your money!final rating: 4/10',
#  290: 'jake gyllenhaal will go place from here, and the supporting cast was superb.',
#  291: 'even at $6.99 it seemed a waste of money.',
#  293: "including the intriguing selden played by tim mcinnerny, arthur conan doyle, a compelling role played by dougla henshall and brian cox as the 'role model' for sherlock holme, dr. bell.",
#  300: 'this is not the worst film i have seen of peter greenaway but it is close.',
#  308: 'there are endless shot of our protagonist driving, getting in and out of car, driving again, walking around looking at stuff, getting in car and driving... i just sat there watching endless parade of nothingness in stupefaction muttering "say something, please somebody, just say something... do something...',
#  311: 'william h macy, three heavenly word, and his performance as the shoveler is pitch perfect.',
#  312: 'where soderbergh wishes to demonstrate che is virtues we see it in small episode such as the loyal acolyte who upaids two fellow guerrilla when they question che is leadership, and emphasises the sacrifice that he has made in leaving behind cuba to fight again for revolution.the direction throughout is superb.',
#  313: 'but at least there is been that naturalism in the way both attacked their role that made us forget the banality of the movie and watch the performance.madonna, on the other hand, not being an especially gifted actress capable of really letting us in on her ability to convey a persona other than herelf, fares much worse, and even in the hand of someone as woody allen in shadow and fog (1992), an inferior classic, she in her pat screen time seems stilted and a little stiff, maybe even nervous, as if she were aware of the camera and crew and just could not let go.so here she tries yet once again to prove she can act in what is essentially a two-character movie.',
#  315: 'their devotion to each other is evident right away, and as the ravage of aid escalate and become the focal point of their life, you see strength and commitment that are truly heartwarming.when "silverlake life" was originally released, i was deeply involved in hiv/aid education and health care, volunteering as a counselor at an hiv/aid clinic.',
#  316: 'every episode i have sat through was like a lame, watered down version of a star trek episode, minus anything that might make it interesting or exciting.it is basically a bunch of person standing around in army fatigue, talking about something boring, who occasionally go through the stargate and end up on a planet that looks just like earth, with person who look and sound just like human!',
#  322: 'the concept was more original than most direct-to-video movie and they did not use sex to make up for a thin plot.',
#  323: 'his suspicion are so weak that the bad guy have nothing to worry about.',
#  326: 'when i was a 3-year-old kid living in the philippine, i would watch this show every friday on abs-cbn (channel 2 over there).',
#  327: 'this movie is truly one of the worst movie i have ever seen.',
#  334: "these are the type of effect a director might normally utilize to show a character's perspective while on drug, except in this case they seem to have been sporadically tossed in at random point, in some cheap attempt at style.despite its cast of relative unknown, performance were good all around, most notably with respect to the main antagonist (corey large).",
#  335: 'sadly, though, the "babylon 5" pilot movie has an incredibly dull story involving assassination.',
#  339: 'if the big budget movie do not work then why make a low budget made for t.v.',
#  341: 'this infamous italian is mostfamous for "zombie," and the absolutely unwatchable "thepsychic" and "manhattan baby."',
#  344: 'which is why this show embodies everything i need in a program when i get home from work in the evening: superficial conversation in the background with just the right amount of "cute" to the character for me to enjoy when i eventually look up from the computer to see what i am missing.funnier than most of today\'s sitcom, calmer than an evening at nascar.',
#  345: 'this is a lovely tale of guilt-driven obsession.matiss, on a lonely night stroll in riga (?)',
#  346: '(in various language with english subtitle) grade: 8/10 (b+).',
#  349: 'despite the mysteriously positive review and high rating, this is an awful movie.',
#  351: 'the writing is just bloody awful, and the actor cannot be faulted for the terrible thing they have to say.',
#  353: 'the makeup work of the late stan winston is pretty good too, but it does not get much of a showcase here.',
#  359: 'i found the documantary entitled fast, cheap, and out of control to be a fairly interesting documantary.',
#  360: 'in fact, i turned it off after watching it for 45 minute and figured a week later that i should watch the whole thing no matter how slow it was.the movie has good spot in it, but you have to wait and wait and wait.......for them.if you are into b movie, this might just be for you, just be warned that the movie is slow and not much really happens, and did i mention not much story line either...',
#  361: 'armstrong.the music is spooky and gives that devilish chill!i liked the effect on the dog and i think the creature itself looked really cool with its horn,frill like part on his neck, and acted really viscous!if you like horror film and have not seen the devil dog: hound of hell before and are able to find and buy this rare film then do so because its a good movie and i do not think you will be disappointed!',
#  367: 'great storyline with a romantic, horrific, and ironic plot.',
#  369: "perhaps ten year later the 'psychological' western was well entrenched but in 1950 it was rare to throw ahab into the mix with cain and abel, to say nothing of addressing several other issue along the way, and still furnish a conventional western on the surface and full credit to all concerned.",
#  373: 'plot is terrible, acting is even worse.',
#  379: 'the gospel of lou was a major disappointment for me.',
#  380: 'anyone growing up in an italian family will definitely see themselves in these character.',
#  381: 'this film was like a book that you cannot lay down, and when you have reached the last page wish for more...still more.',
#  383: 'the movie is not a cop-out, exactly, but it is a fraud, handicapped further by the bad editing, the poorly-conceived flashback, the low-budget production, and the big finale which smack of silly pretension and soapy melodrama.',
#  385: 'even the main villaness refusing to wear clothing other then a loincloth is pretty boring as she pretty much has a chest of a young boy.mildly amusing in it is ineptitude at best and severely retarded at it is worst.',
#  387: 'an illegal immigrant resists the social support system causing dire consequence for many.',
#  396: "impressively directed and surprisingly well thought through, the soft rock and country and western song are sometimes a distraction, especially when they feature english lyric sung by japanese singer who audibly can not pronounce the word let alone speak the language, but it is a forgivable flaw in a surprisingly good sci-fi actioner.optimum's uk dvd is a good transfer of the uncut 138-minute version.",
#  397: 'the show kept me up friday night back in my high school year, and provided some of the best drive-in memory to ever come outside of the drive-in.without a doubt, the best late night television ever.',
#  399: 'possibly xtro (nasty and dull) or possibly creep (just plain dull), but it is a struggle to think of something worse.',
#  401: 'however, it also conveys so well this sort of clichéd, rebellious desire to get out of the existence which both mark and daria must share.',
#  407: 'else, nothing would have made me sit beyond interval.this movie is nowhere close to sholay.',
#  408: 'you either see it or miss it and there is no time to observe, to comprehend.',
#  409: 'the style of art is beautiful, the sound is perfect, and the symbolism within it is eathtaking.',
#  410: 'lupino is very powerful in this role and plays off colman very well.',
#  411: "word to your mother.want me to stop?that is just a small sample of the stupa-fly style of rhymin' on display in this waste of film and location permit.",
#  413: "however what makes griffith's cross-cut so effective is the way he paces the opposing image so they complement each other.",
#  418: 'sunny learns her way around the jungle of the u.s. government very, very well.',
#  420: 'i ran out after watching this to buy the dvd, obv not easily forgotten!the script is illiant, and the casting could not be more perfect.',
#  422: 'screening)... i saw this film in atlanta almost directly after being involved in a rather devastating car crash, so i was slightly dazed at the time, which was perhaps a very good state of mind to watch the prophetic talking arthropod and the retard in the superhero costume and godlike glover in his appropriate burly-q setting, scan notily clad girly rising out of the floor like a magnificent dadaist wet dream.is it a statement on life as we know it?',
#  423: 'thank a million for restoring our faith in human nature.',
#  424: 'is it supposed to say that if you want someone badly enough, it is ok to hurt everyone else along the way?',
#  426: 'this vague necrophilia reference is offensive enough; but in light of the murder committed shortly after this movie was released, it is truly appalling, and therefore entertaining in an unintentional, horrible way.',
#  428: 'johnny dangerously is at least a completely innocent gangster film spoof that even relays some well meaning message about the danger of smoking (and sex).i like it but it is hard to recommend.7/10.',
#  431: 'not only is this a coward way to kill an enemy, it is more like a ninjas way; silent assassin; a group that samurais deny exist, but hates none-the-less.then he tries to kill his boss, when he finds out his boss is a baddie.',
#  433: 'i seem to recall that this version sticks closer to the original story than most other--but i may be mistaken, as it is been several year since i read it.',
#  438: 'i am desperately trying to find something nice about this, i can not except walken did a fine job with a wooden character.',
#  439: "i would not fault the acting - the show would have been much worst if not for wu's acting which was the film's only saving grace.",
#  447: "this is also true for german film maker sylke ender as her film's principal protagonist kroko has been mistreated by everybody around her including her mother and boyfriend.she is bold enough to face any punishment as she has tried her hand at all kind of criminal activity including shoplifting.kroko was originally shot on dv to be blown afterward to 35 mm format.it technical virtuosity does not hamper our joy when we learn that kroko would like to become a policeman as she feels that she is averse to the idea of becoming a run of the mill hairdresser.if someone were to state a positive aspect of sylke ender' film,it may well be kroko's involvement with handicapped person as a result of a punishment.it is with kroko that we learn that punk are human too with their unique joy and sorrow.",
#  450: "whether this scene was cut just for time or because it did not provide much fodder for riff, i do not know.another plot point missing in the original: the stripper's betrayal of venantino venantini to joe don baker, seemingly unmotivated in the mst3k version, is explained by an earlier, extremely unpleasant scene in which venantini rapes her in the shower.",
#  451: 'the show is very intriguing and they have wonderful storyline and their stunt are amazing.',
#  457: 'i see nothing redeeming about this film at all, save for the eye-candy aspect of it...3/10 (and that is being generous)',
#  459: "the much hyped and over-confidently promoted tashan poorly bombed at the box-office which it certainly deserved.in my view, this is the worst movie ever made from honourable yash raj film' banner.",
#  460: 'the plot is not even the worst part of this movie.....its the acting, camera work, lighting, and sound.',
#  462: 'while i did not mind the pacing due to the beauty and suspense of the film in question, i do think that it will both most person.',
#  466: 'sharon stone is gorgeous and does a great job in the movie and it mystifies me as to what in the hell the critic want',
#  467: 'sure it was a little hard to understand it is quite obviously low budget, but it had a very hitchcock-like plot and i can honestly say that when i viewed the non-mst3k version, i was genuinely entertained.',
#  469: 'this one is definitely worth renting if you have kid and want to watch a movie with them.',
#  471: 'these were the day when the teacher still showed classroom film on reel-to-real and if you were good, they would rewind the movie slowly so you could watch it play backward.',
#  474: 'her love for christy and constant fighting for him just seems so convincing and heartfelt and she earns a lot of sympathy given her situation.the emotional punch of the film given the story is surprisingly minimal.',
#  476: 'if you do not have the original director and actor handy...you are just looking to get your butt whooped.in the sequel, our story begins with a slightly older ariel and her daughter, melody.',
#  478: 'the acting is pretty bad, the story seems unimportant, the killer is not cool or scary, and it suffers the one major error that any slasher flick should always avoid: it is a bit boring.',
#  482: 'the passion to which artemisia gives to her art is just spectacular to watch.although not each character was overtly beautiful, this made the film more realistic as the facial hair and clothing was perfect for that point in time.overall i thought this film was fantastic.',
#  483: 'apart from the expected combat photography/action, there are plenty of personal, emotional and human tragedy that are told giving the viewer an amazing insight, especially if you are not necessarily a world war 2 buff/fan.',
#  484: 'boring, pointless, utterly stupid "horror" film.',
#  485: 'sometime next year it should be available on dvd and hopefully also released on hd dvd.',
#  487: 'they are the lame sort of predictable joke that your unfunny friend would say.corky romano is about a mild mannered vet that tries to do right but is so clumsy.',
#  491: 'supposed to be a comedy.',
#  499: 'minus the hollywood exaggeration, the race thing hit pretty close to home for me.',
#  501: 'once again, this director ings together a wonderful cast of everyday person (not actor) and gets a great ensemble-type performance.',
#  503: 'peet is the common denominator who dates the three bachelor in the group which leads to conflict and the inevitable "whipping".',
#  505: 'i went out and rented this movie and i have to say it is the most heart-wrenching film i have ever seen.',
#  509: 'i was shocked and surprised by the negative review i saw on the web, i thought cinderella 2 (as well as 3) is a very cute and funny sequel for everyone - kid and adult...like me, i am 22 year old.i also find it and very informative film, it shows lesson on being true to yourself and following your heart.',
#  512: 'from the opening scene with the poorly-done effect to the "monster" from another world and then the house which jumps from universe to universe was as achingly painful as watching an elementary school production of \'the vagina monologues\'.throughout the film, the sure sign something was about to happen was when a small ship would appear.',
#  513: 'the ending does not save the film either.',
#  516: 'the shootout scene in the carnival hall of mirror is one of the most amazing ever filmed.',
#  517: "the camera motion, color, lighting, compositing all contribute to the story and emotion of the film.and music, as a key element of film language, helps a great deal too.it is hard to portray a woman's heart, her desire, her fear, especially in a short.",
#  520: 'if you want to have a laugh and see one of the most poorly done, low budget mess of amovie ever created, then i would recommend it for that, and only that.it is a wretched, poorly made, poorly edited, poorly paced and tedious piece of low budget drivel that fails on all count.',
#  531: 'nice humour and fantastic kung fu this movie rocks!',
#  535: 'then, some sort of spirit or alien or something appears and saves her (thing that make you go huh?).',
#  536: 'tom brown was an excellent gilbert blythe.',
#  538: 'but how clarke can convince us that any of the two-bit actor straying from other tv production of low quality (grange hill) or soon to go on to poor quality drama (eastender) can for a nanosecond make us believe that they are tough football thug is laughable.',
#  542: 'he is actually quite good here, but the story is a mess of b-movie clich (detective, revenge, tycoon, hooker, sandm) that looks like it was made up as they went along.',
#  547: 'the only "full length motion picture" of the church\'s i had seen was "legacy" and "my best two year", both which i thought were very well written and preformed.at the beginning, the missionary interpretor passed out tissue stating that several person had been deeply moved to the point of tear by this movie.',
#  549: "i love the director's portrayal of the relationship of the two daughter--as one of six sibling, it is clear to me he understood how complex those relationship are.",
#  550: 'it was just a bare masochistic tendency of mine that caused me not to stop watching, add to that the group pressure from my co-watchers.the manuscript is awful, the directing even worse and the acting is plain despicable.i hope you do not see this as a spoiling your fun, i would rather see it as a fair warning: do not waste your time watching this garbage!',
#  553: 'no wonder movie revenue are down.throw your $6 down the toilet and save yourself 2 hour of your life you will never get back.ciao, freddyshoop',
#  554: 'it takes place in the beautiful country of new zealand, amongst the scenery we have come to know so well through other film from this region.this movie was the first time i had ever seen the excellent mary regan, and i have been a fan of her ever since.',
#  558: "every character's purpose was to fill a silly 60's archetype.take how we are introduced to finnegan: hugging his black maid and receiving a framed picture of mlk.",
#  563: 'hopelessly inept and dull movie in which the character stand around in room or a rocket ship and talk endlessly.',
#  575: 'really bad shot on video "film" made by not one, not two, but three amateur video makers.if you are going to make a bad horror film at least throw in some blood, gore and nudity.',
#  576: 'i caught this on (a surprisingly feature-filled) dvd and it scared me silly.',
#  579: 'do not send an assassin, it is much more sensible to smuggle hundred of ightly colored, aggressive, venomous snake on a plane!',
#  580: 'the fruit of good deed is good, while the fruit of evil is evil.',
#  584: 'to sum it up, this is pure cinema barf drenched in the chocolate syrup known as nudity, and topped with the cherry of horrible acting as only a porn star could deliver.',
#  585: 'the movie was too serious, too overdone, had too much of a plot and was not even remotely as funny.tip for those who have not seen it: never see it.',
#  586: 'definitely worth a look.',
#  592: 'it is many things- stupid, pointless, and worthless to name a few.',
#  601: 'it is so good see a show where all the character work well together and they treat each other with respect.',
#  604: 'not to mention that many of the main character are not from the region in which this story takes place (and it is blatantly obvious with name like lee and hernandez).',
#  606: "frannie strongly objects to the idea, and vow to keep the family heirloom as it were, by getting a job and maintaining responsibility.in comes handsome ruben and the two soon fall in love (as you do), and it is from this point that i sort of lost interest....there is more to farrah fawcett than just the blonde hair and looks, she can portray a character extremely convincingly when she puts her mind to it - and it is certainly proved here as well as some of her previous effort like extremity and small sacrificy - a great performance from the legendary charlie's angel.silk hope is the type of film that never shies away from its cheap and cheerful tv image, and you know there was a limit to the budget, but it is not the worst film ever made.",
#  608: 'a lot of movie-material is wasted on crew member putting film spool in the camera and dragging around cable or \x96 even worse \x96 faith domergue and charle macaulay portraying horridly intolerable actor stereotype.',
#  610: 'this movie basically falls apart after the escape from the jail (i fell asleep about forty minute into it).',
#  616: "hoping to discover the source of these signal and who's behind them, the scientist and his wife set out on a trek to locate the intended recipient of the signal.",
#  618: 'this was my first glimpse at both reese witherspoon and jason london, both of which are two of my favorite.',
#  621: 'oman iv (1991) was a bad made-for-t.v.',
#  624: "unfortunately for 'attack of the killer tomato' spoof film such as the 'airplane' and 'naked gun' series have been released and done this kind of comedy a lot better since.the acting is atrocious; there is zero continuity in the editing and it just feels genuinely slow and lacking energy.",
#  626: 'i have a lot of time for all the columbo film, but this one in particular was extremely well written, and the solution at the end very effective.',
#  631: 'this film starts out like a run of the mill western but gets more complex as it goes along.',
#  635: "he social-engineers his way into a london man's club and learns the identity of the best computer expert in town, he steals the identity of one caesar smith, who has just left town for south america to pursue his hobby of collecting moth in the wild.",
#  638: 'the writing was truly terrible and i am not surprised that the writer are those responsible for the worst australian film in recent memory the honerable wally norman.nothing about this tv series was funny - ever - not even mildly amusing.',
#  640: 'this naturally makes the contestant sweat and causes further delay as the nervous contestant contemplates the sudden loss of the hundred of thousand of dollar.',
#  643: 'stan and ollie become sap at sea when their wayward little boat is commandeered by a vicious murderer.the boy are wonderful in this feature, which starts out with one of their most hilarious set piece, the horn factory.',
#  644: 'only on a very rare occasion does an episode of the x-file fail to generate any excitement or does the episode contain anything which is just totally boring to watch.a detective and his former partner both die in unexplained circumstances.the death are linked to the presence of a little girl who was there when the death took place.mulder has devised a theory that a policeman murdered by his colleague has come back reincarnated as the little girl and is exacting revenge.now for the bizarre bit.the little girl has no connection at all and seems to just a random person chosen as the reincarnation.i think this was slightly lazy writing by the writer and this episode ranks as one of the worst in x-file history!',
#  647: 'also, my 7-year-old daughter liked the angel effect!',
#  649: 'a nice story pretty well put together- by canadian, quelle surprise.',
#  651: 'somewhere, in a confuse manner, a problem remains unsolved, the emotion grows with the rhythm of the movie until somebody dy, just one life, nothing compared to so many other fiction or reality we can see today, because this death, this unique vanishing life i lived it, i shared with my child unconditional friendship.',
#  655: "i have had dorthy malone in my spank bank most of my life ,maybe this was the film that impressed me.loren bacall sure did have some chop in this film and probably out-acted malone but malone's part made a more sensational impact so she got the oscar for best supporting role.was loren's part considered a leading role?old man hadley character was was probably a pretty common picture of tycoon of his era in that he was a regular guy who made it big in an emerging industry but in building a whole town he had forgotten his child to have his wife ing them up.in time,being widowed he realized that they were all he really had and they were spoiled rotten,looking for attention,so rather than try to relate to his child he blew his head off.an ancient morality tale.but seriously,what were those sport car?",
#  657: 'how could the writer and producer of this stinker turn this into such a dull story?glenn ford, as the expert called upon to defuse the bomb, is given awful writing material to work with.',
#  664: 'unless you are like me and just can not resist the opportunity to see what may truly be the worst movie ever made.',
#  668: 'a story of obsessive love pushed to its limit and of a lovely swan whose beauty is the very ticket to her own premature demise.',
#  673: 'well made and stylish while still ultimately making sense this thriller would work better for non giallo fan to get interested in the genre than the later argento entry which go overboard in all directions.for fan of these crazed italian thriller, they will appreciate george hilton and the turn his character takes and what he is put through.',
#  674: 'mellisa you are like 40 year old and you still throw temper tantrum?',
#  681: ')this film is an awful, ignoble american ainwashing instrument, full of error, lie, propaganda, prejudice and injustice.',
#  683: 'if you love bringing up baby, the philadelpia story, the thin man, i was a male war bride or it is a wonderful life - movie made with wit, taste and and the occasional tongue firmly panted in cheek, check this one out.',
#  686: 'very bad acting very bad plot very bad moviedo yourself a favour and do not watch it 1/10',
#  688: 'after that, however, the whole thing turns into a tedious, unstructured and insufferably amateurish mess.',
#  695: 'but everytime it gets funnier.trust me on this one...baseketball is a surefire hit and i loved it and will continue to love it.',
#  696: 'pecker is a hilariously funny yet twisted film about a small town in baltimore whose daily, humdrum routine is oken by pecker, a young photographer who takes picture of "real thing."',
#  697: 'try to look for something better.',
#  701: 'if the point of this film was to show how pathetic a life rosetta had, then it was covered within the first fifteen minute of the movie and then the credit should have been running.',
#  705: 'all three are overcome by the sudden reality that college life is not as good as it is advertised as all three go through disappointment by being unprepared (malik), by being naive (kristin), and by being unwanted (remy).one good thing about the film is that it does show that modern american college are just high school writ large.',
#  707: 'this is a film about person who find the courage to choose and experience life because of that choice.',
#  708: 'i can not tell you how to waste your money.',
#  711: 'as other reviewer have pointed out canadian movie are generally poorly written and lack entertainment value, which is what most movie watcher are hoping to get.',
#  714: 'the last time i checked a host does not discriminate, spew hatred filled rant on tv, or try to shove their own belief down every unfortunate soul that venture onto the channel.',
#  715: 'it is acted well by a good cast that does not try too hard to be star studded.the premise of a newly widowed housewife who turns to selling pot to make end meet could have been made into an americanised turd of a movie or an action thriller.',
#  718: 'even the nasal singing sensation song could not make up.this movie is good for a lazy sunday afternoon and is really refreshing if you have not watched the original tv serial.',
#  720: 'we have a typical family filled with cliched character (father a war veteran who lost his wife and blames himself lolol), air-head child trying to hard to fill the stereotype but fails with horrendous acting, and a laughably horrid sidekick who serves no purpose to the movie but to fill camera space.',
#  724: 'in general i thought the attitude and the atmosphere of the production conveyed the charm of the novel exceedingly well; indeed it is one of the sweetest, merriest thing i have ever seen, rather in the nature of a christmas treat.',
#  725: 'i put it in three machine to see what was wrong.',
# ...
#  2790: 'there is only one movie that i have seen that i can honestly say was bad...and this was it.',
#  2794: "larry peerce's direction waver uncontrollably between black farce and roman tragedy.",
#  2796: 'this movie is to show what those "genius" person very often think and what problem they face.',
#  2797: 'joan plowright is superb as "phoebe", mike kopsa is hilarious as "coach" and richard de klerk plays the role of "carmine" superbly.',
#  2799: 'there are obvious problem; for example, after taking what seems to be week and week to get from fat to normal size, the main character seems to go from normal size to deathly thin in day... and once he is deathly thin he stays pretty much equally deathly thin for what seems to be a long time.in any case, the movie has far worse problem than that--the cinematography is decidedly low-budget-tv-show quality and most of all the acting is pretty awful all around.',
#  2805: 'this show manages to capture the feel quite well, as they state on the ste, it has improved over the year with experience and i hope with some more experience, a strong script editor, and a pick-up in timing and cgi that hf will becoming more remarkable than it already truly is!good work to all concerned!',
#  2806: 'ok, to sum it up: very emotional if you have lived through it, but you will spot minor improvement that could have been made as well as plot necessity that were.',
#  2812: "without spoiling, i can say that i was very moved by the movie's approach to living.",
#  2813: '1/10.seriously.',
#  2814: 'but to me it is the peerless golden music by ghulam mohammed as sung by the incomparable lata mangeshkar - especially thare rahiyo - and its part in the unfolding of the story that makes this film so outstanding.',
#  2826: 'it was on at 7:30am, too close to school to see very often.',
#  2830: 'but one workable idea (interaction between real bussinessman and russian mafia) is not followed by an intelligent script',
#  2838: 'maybe i am expecting too much for a lifetime movie played 15 day from christmas but i sat through this thing thinking that with a different director and a recasting jj with an actress that at least could elicit sympathy this could have been quite a cute little movie.',
#  2842: 'and zhang ziyi, what can i say, a few line, terrible acting (but that is based on her script).',
#  2848: 'however, as they say, the very thing that works for you can also work against you.',
#  2851: "it is composer jame horner's finest soundtrack ever and evokes so much from the film and the audience.",
#  2855: 'my child (10, 7, 5, and 4) all loved this movie, including myself.',
#  2856: 'al pacino is like the jack nicholson in batman and plays big boy caprice with zest.',
#  2858: 'i had no emotional attachment (except to the big bad machine that wanted to destroy them) scene were blatantly stolen from other movie, lotr, star war and matrix.',
#  2859: 'maybe i am missing something.. i just can not believe a movie like this can beat a classic like hddcs!',
#  2862: 'but what i saw just oke all my expectation - in a good way.the storyline is not complex and shows us a life of found boy- orphan and particularly his connection into the community of poor person who together built themselves a hood of simple metal plate house.',
#  2864: 'there was a genie played by shaq his name was kazaam, and he was whack his rhyme were corny, this line were bad some stupid kid cryin over his stupid dad bad actin, bad casting, bad special effect what next?',
#  2870: 'and whether it is wheedling his way into the affection of the waitress at his favorite hangout (the sleek claire forslani), or questioning the wisdom of a fellow superhero (wes studi as the sphinx), or giving a new member of their "elite" group (jeaneane garofalo in what are possibly her funniest momants on screen) a hard time, he makes it always fun to watch.',
#  2872: 'as of typing this, i am surprised it is at a 5.2/10 on imdb.',
#  2874: 'i usually like gina phillip, but this one i have to say was a bad choice just like her doing the movie ring around the rosie, that one also not one her good movie.',
#  2876: 'they are both excellent actor and play the main role of antonietta and gaiele.',
#  2878: 'i was shocked by tiresome scenario, poor acting and producing, and a lot of inexactitude of "space race".the movie is the tedious rendering of well-known in russia historical fact.',
#  2879: "trey parker and matt stone, the creator of the show 'south park' , return with something entirely different.they create a new sport that combines baseball and basketball.this sport is known as baseketball.it is like basketball except that the rule of baseball are involved and there is another letter e in the title.here is how you play: you just shoot the ball while these two guy try to distract you from making the shot.sound simple.in fact, i might try it one day.after the game hits the street, it soon becomes a huge success.who would've known that 2 immature friend could invent a sport that became so successful?my opinion'baseketball' is a very crude and silly spoof filled with lot of slapstick violence, yet it actually delivers some laugh and plenty of entertainment.a definite recommendation for those of you who like slapstick and rude humor.",
#  2884: 'this is a great movie that everyone should see.',
#  2885: 'to prove his point, he produces a time machine (put in the movie solely to make the plot work, which i am fine with), and sends carlisle to the year 2002 to see where teaching morality without god will lead us.as should be obvious, he has his opinion, and is changed by what he sees, and has reversed himself by the time of his return (for he does return, that is not really a spoiler, this is a bible movie after all).as for the movie as a movie itself, it is pretty slow and pretty poorly acted.',
#  2893: 'this clunker reminded me a lot of another lugosi stinker,"the devil bat"....same silly plot line and bad acting and same silly \'reporter gets bad guy\' deal.but lugosi is always good--he is creepy and sinister enough to keep you interested at least enough to keep watching him.the woman playing the reporter was just a terrible actor....she had no emotion whatsoever,she just delivered her line like a machine gun ,spewing them out as quickly as she could.everyone else pretty much blew too,when it came to being good actors.but this thing is watchable ,if only for bela lugosi fan.lugosi was always so intense even when the picture was a dog.he must have known he was doing terrible picture but maybe he also knew that if he gave it everything he had a little of that intensity might shine through past all the bad plot and bad acting which surrounded him.and he was right----we horror fan will always have a love for bela lugosi.he gave it his all every time he was in front of the camera.we do give two f**ks for you,bela.',
#  2897: 'i am not saying that urban crime was not a problem for a lot of person or that school were not/are not problem area but this vile piece of exploitation takes the biscuit.',
#  2898: "it was completely predictable, trite and boring.from the first 15 minute, the rest of the movie was laid out like a child's paint by number routine.",
#  2900: 'the plot has something to do with a woman marauding around; practicing sandm and talking rubbish, and it is all really boring.',
#  2904: "it looked like bollywood finally gave away it is glamor and had some quality artist performing on screen.content wise, the movie depicted very much what exactly happened during partition by showing the suffering of a particular family and also shows that trust in one's life goes beyond religion.the best part was they did not make it a drama with a lot of tear shedding and melodrama.i simply loved it.",
#  2905: 'fatty drives the bus is simply the funniest, most original and entertaining piece of work i have ever had the pleasure of seeing.this movie is by no means up to hollywood standard, or even that of a straight-to-video movie fluff comedy starring terry "hulk" hogan, in term of camera work, editing, acting, budget, or anything else.what this movie does have though, is a very original and enjoyable story, and it is obviously done by person who love making it, and the enthusiasm of the all the cast and crew really eak through all its budget and acting downfalls.this movie proves that you do not need a huge budget or decent actor to make a great film, all you need are some original idea and some passion for what your doing.simply the best movie ever.',
#  2906: 'this has to be the worst piece of monkey s@#t i have ever seen!',
#  2907: 'earth (2009) ***1/2 big screen adaptation of the bbc/discovery channel series "planet earth" offers quite a majestic sampling of nature in all its beauty with some truly jaw-dropping moment of "how the hell did they get this footage?!"',
#  2909: 'well, if you are looking for a great mind control movie, this is it.',
#  2910: "who is very pretty, but really no more than a mediocre actress.overall, this film comes off like a poorly written, flaccidly acted and shockingly directed attempt to copy 'the hitcher' and 'spoorloos', but it fails at every turn due to a lack of talent in everyone involved.",
#  2912: 'the absence of violence and sex was refreshing.',
#  2915: 'i do not recommend this movie to anyone unless you are purposely trying to watch the worst movie of all time.',
#  2918: "i guess the director is a gay man in denial, or something like that.so my advice to you is: if you want to waste good money, go rent a good comedy you have already seen a million time, you will be better off than watching this mother of all lousy comedy's.",
#  2919: "julie water is outstanding and adrian pasdar a revelation in a very warm, very real, and extraordinarily entertaining look at the complication gender dysphorium and transvestism cause in a young executive's life.",
#  2923: 'the grainy bandw film and photo capture the time and the introduction of color in miami beach through the photo of bunny yeager is very well done.the supporting cast is strong with david strathairn (fresh off his edward r. murrow role), chris bauer (as irving klaw) and lili taylor.',
#  2927: 'almost every scene has some bit of humor: running gag, slapstick, and great joke.',
#  2929: 'in the film version, a blond bomb-shell as brown, tries romantic entanglement.television star ray walston has a small role as a government agent, or is he really that?a very big disappointment for those who enjoyed the television show so much.',
#  2930: 'third, this woman is that tremendously beautiful that i suggest the director retire all those cameron diazes, eva mendezes, and how ever the name of these ephemeral bulb-light are.',
#  2932: 'lena, in a radiant performance by reimann, discover that her husband and other jew are being held prisoner in a former factory on the rosenstrasse.standing together in the freezing night, german woman whose husband are missing congregate outside the building, their number growing daily until they reach one thousand shouting "give us back our husband".',
#  2935: 'this, along with "hare tonic," ranks as one of the best bug cartoon, indeed one of the best bug, ever.',
#  2937: 'who would green light something so poorly written?',
#  2938: 'but i will recommend that you go straight to your nearest moviestore right now and rent it!',
#  2943: 'very definitely worth seeing and seeking out - you will never forget it, but very disturbing.',
#  2946: 'the sequel, however, is not only a shameless attempt to capitalize on the good name of the original but also a ridiculous, overblown disneyfied mess best summarized as "rambo meets the black stallion."',
#  2947: '3/10.',
#  2948: '- but realize after twenty minute or so that you just can not turn it off, no matter how bad it is.',
#  2950: 'through lena, daniel learn to love , something he has longed for, and now finds fulfillment .the solo sung by gaiella , composed by daniel, is all about living a full life , in contrast to moral correctness that leads to concern about sin , and what is right and wrong.',
#  2958: "the lady from shanghai is not exactly a nose-thumbing at the studio moguls of the day, but i suspect that it is, in its portrait of amoral, rival big shot lawyer (read: producer) expressing welle' opinion of the power oker of hollywood.",
#  2959: 'and the acting, while not awful, is amaturish at best.in addition, if you are not either a mormon yourself, or very, very familiar with mormon culture, you will not get hardly anything at all.',
#  2966: 'the love triangled threesome eventually wind up in france, with the great war (world war i, in hindsight) complicating their life considerably.a mostly entertaining, if propagandistically flawed, cecil b. demille film.',
#  2968: 'once you know this, however, you can well appreciate the full sctv style craziness that transpires.',
#  2973: 'i can say that it is the best film i have seen all year.',
#  2974: 'not only is the writing atrocious and the joke awful, but the camera work and film quality are amateur at best.',
#  2981: 'this is easily the most underrated film inn the brooks cannon.',
#  2988: 'while the film focuses on the revolutionary nature of lsd and it is dissemination at the time, that alone played a tremendous hand in the evolution of the intelligentsia, influencing engineer, scientist and aiding in the hyper-development of computer related activity.',
#  2992: 'on first watching this film it is hard to know quite what has happened, but on a subsequent viewing it become more clear.',
#  2993: 'you will get to see elizabeth shue, whoopi goldberg, teri hatcher, and carrie fisher...to name a few...all give splendid performance.',
#  2998: 'not a great movie, but worth seeing.',
#  3000: 'it is a movie that deserves to be seen, appreciated, and enjoyed, a film that is rare and delicate, and it is not afraid to be classified as fun!',
#  3001: 'generically speaking, fay grim is a highly entertaining thriller featuring two of the most inexorably enjoyable name in american movie, unshakably beautiful and gracefully spunky parker posey and endlessly charismatic and unavoidably hilarious jeff goldblum.',
#  3002: 'it is always entertaining.aardman animation shows great imagination in the character used for each voice, the single aspect that i probably love most about the show and its concept (the hostility between the pandas, the porcupine discussing fear of needle, the painting ape).',
#  3008: 'it is also very refreshing to see a film where the character are all friendly, kindhearted folk and not unmotivated character that are clearly labeled as being either "good" or "evil".richard farnsworth turns in a beautiful performance as do the rest of the cast, most notably sissy spacek in an endearing performance as his daugher, and harry dean stanton in a small but infinitely crucial role.with this film, david lynch proved to critic that he could make a powerful moving motion picture just like he did in the 80\'s with \'blue velvet\' and \'the elephant man\'.',
#  3011: 'it is so sweet watching dani fall in love and it eaks my heart and yet warm my heart at the same time watching court fall in love with maureen.',
#  3014: 'this story is a complex and wonderful tale of the last harem of the ottoman empire, well told and provoking we see the inner working of a world now gone, and learn about the person who lived there.i enjoyed the story, character, acting and scene.',
#  3015: 'i word on fx, i can tolerate really crappy cgi but the script has to rock and this one was just too slow, spartan and lacking in drama.',
#  3018: 'the actor did pretty well, but it was not up to them save this bunch of crap.',
#  ...}

# %%
len(chosen_sentences)
# Out:
# 25000

# %% [markdown]
# Relevant Sentence Model

# %%
from sklearn.svm import OneClassSVM
from sklearn.metrics.pairwise import cosine_similarity

# %%
chosen_corpus=list(chosen_sentences.values())
# chosen_corpus

# %%
# count vectorize the chosen_corpus

svm_clf = OneClassSVM(kernel='rbf', random_state=42)

# %%
X = tf_vectorizer.transform(chosen_corpus)

# %%
X
# Out:
# <25000x26266 sparse matrix of type '<class 'numpy.int64'>'
# 	with 676323 stored elements in Compressed Sparse Row format>

# %%
svm_clf.fit(X)
# Out:
# OneClassSVM(cache_size=200, coef0=0.0, degree=3, gamma='auto', kernel='rbf',
#       max_iter=-1, nu=0.5, random_state=42, shrinking=True, tol=0.001,
#       verbose=False)

# %%
# need to extract sentence for each doc
# and use decision_function (predict)

svm_clf.decision_function(X[:10])
# Out:
# array([[  3.89802165],
#        [ -4.69473815],
#        [  0.90259644],
#        [ -6.62202232],
#        [  3.55835032],
#        [-28.07471014],
#        [  1.37904705],
#        [  2.87247895],
#        [ -9.36394717],
#        [ -0.42607689]])

# %%
j=np.max(svm_clf.decision_function(X[:10]))
j
# Out:
# 3.898021654051263

# %%
chosen_sentence=[]

for ind, corpus in enumerate(X_test_original):
    '''
    Breakdown the corpus into sentence and transform into bag-of-words
    '''
    sentence_set = tf_vectorizer.transform(TextBlob(corpus).raw_sentences)

    '''
    related sentence classifier
    '''
    svm_decision = svm_clf.decision_function(sentence_set)
    mr = np.argmax(svm_decision)

    # no threshold?
    chosen_sentence.append(TextBlob(corpus).raw_sentences[mr])

# %%
len(chosen_sentence)
# Out:
# 25000

# %%
X_chosen = tf_vectorizer.transform(chosen_sentence)

# %%
clf_i.score(X_chosen,y_test_original)
# Out:
# 0.64752

# %%
clf_j.score(X_chosen,y_test_original)
# Out:
# 0.62656
