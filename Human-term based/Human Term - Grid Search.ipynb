# %%
from keras.layers import Input, Dense, TimeDistributed, Embedding
from keras.layers import Concatenate, Reshape, Lambda, Multiply, multiply, concatenate
from keras.models import Model
from keras import backend as K

import os
# os.environ['CUDA_VISIBLE_DEVICES'] = ''

import tensorflow as tf
import numpy as np
# Out:
# C:\Users\Anneke Hidayat\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# load data
# make sure that the first shape is the IMDB training data. 

def open_pickle(path):
    import pickle
    with open(path, 'rb') as f:
        X = pickle.load(f)
    return X

X_train_original = open_pickle('../data/imdb/imdb_original_preprocessed_xtrain.pickle')
X_test_original = open_pickle('../data/imdb/imdb_original_preprocessed_xtest.pickle')
y_train_original = open_pickle('../data/imdb/imdb_original_preprocessed_ytrain.pickle')
y_test_original = open_pickle('../data/imdb/imdb_original_preprocessed_ytest.pickle')

# %%
# Count vectorizer 

from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(min_df = 100)
X_train = cv.fit_transform(X_train_original)
X_test = cv.transform(X_test_original)

# %%
def load_unigrams(path, X, y):
    word_list = []
    connotation = {}
    
    with open(path, 'r', encoding='utf8') as f:
        for line in f:
            word_list.append(line.strip())
            
    for word in word_list:
        pos_count = 0
        neg_count = 0
        for i, doc in enumerate(X):
            if word in doc.lower():
                if (y[i] == 1):
                    pos_count += 1
                else:
                    neg_count += 1
                    
        if pos_count > neg_count:
            connotation[word] = 1
        else:
            connotation[word] = 0
    
    return word_list, connotation

def generate_appearance(X_train_corpus, X_test_corpus, word_list, connotation):
    y_train_agreement = []
    for i in range(len(X_train_corpus)):
        doc_agreement = []
        for word in word_list:
            if word in X_train_corpus[i]:
                if connotation[word] == 1:
                    doc_agreement.append(1)
                else:
                    doc_agreement.append(-1)
            else:
                doc_agreement.append(0)
        y_train_agreement.append(doc_agreement)
        
    y_test_agreement = []
    for i in range(len(X_test_corpus)):
        doc_agreement = []
        for word in word_list:
            if word in X_test_corpus[i]:
                if connotation[word] == 1:
                    doc_agreement.append(1)
                else:
                    doc_agreement.append(-1)
            else:
                doc_agreement.append(0)
        y_test_agreement.append(doc_agreement)
        
    return np.array(y_train_agreement), np.array(y_test_agreement)

# 'imdb-unigrams.txt'

# %%
word_list, connotation = load_unigrams('./imdb-unigrams.txt', X_train_original, y_train_original)

# %%
y_train_agreement, y_test_agreement = generate_appearance(X_train_original, X_test_original, 
                                                          word_list, connotation)

# %%
def build_base_model(optimizer='Adagrad'):
    input_layer = Input(shape=(input_shape,))
    tanh_output = Dense(1, activation='tanh', name='tanh_output')(input_layer)
    
    model = Model(inputs=input_layer, outputs=tanh_output)
    model.summary()
    
    return model

#input_shape, human_terms_shape
def build_combined_model(optimizer='adam'):

    # input for base model
#     base_model = build_base_model(input_shape)
    combined_input_layer = Input(shape=(input_shape,))

    # build the hard coded weight for human terms and split the input 
    ht_input_layer = Input(shape=(human_terms_shape,))
    split = Lambda( lambda x: tf.split(x,num_or_size_splits=human_terms_shape,axis=1))(ht_input_layer)

    # get the document prediction
    label_layer = base_model(combined_input_layer)
    
    # multiply the predicion and the human terms absence -> pass it to relu
    dense_layer = []
    for i in range(human_terms_len):
        dense_layer.append(Dense(
            1, 
            activation='relu', 
            use_bias=False, 
            kernel_initializer='ones')(Multiply()([split[i], label_layer])))

    # concat all the result and pass it to sigmoid layer
    concat = Lambda( lambda x: tf.concat(x, axis=1), name='concatenate')(dense_layer)
    output_layer = Dense(1, activation='sigmoid')(concat)

    # build model
    combined_model = Model(inputs=[combined_input_layer, ht_input_layer], outputs=output_layer)
    combined_model.summary()
    

    combined_model.compile(loss='mse',
                      optimizer=optimizer,
                      metrics=['mae','acc'])
    
    return base_model, combined_model

# %%
y_train_tanh = y_train_original
y_train_tanh[y_train_tanh == 0] = -1

# %%
y_train_agreement.shape
# Out:
# (25000, 83)

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

seed = 42
np.random.seed(seed)

input_shape=X_train.shape[1]
# create model
model = KerasClassifier(build_fn=build_base_model, epochs=10, batch_size=1, verbose=0)

optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
param_grid = dict(optimizer=optimizer)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1)
grid_result = grid.fit(X_train, y_train_tanh)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_20 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_21 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_22 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_23 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_25 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# Best: 0.833200 using {'optimizer': 'Adagrad'}
# 0.522400 (0.006081) with: {'optimizer': 'SGD'}
# 0.605120 (0.004240) with: {'optimizer': 'RMSprop'}
# 0.833200 (0.004663) with: {'optimizer': 'Adagrad'}
# 0.690640 (0.008747) with: {'optimizer': 'Adadelta'}
# 0.639200 (0.003653) with: {'optimizer': 'Adam'}
# 0.791840 (0.004609) with: {'optimizer': 'Adamax'}
# 0.509160 (0.011387) with: {'optimizer': 'Nadam'}

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
    
# Best: 0.833200 using {'optimizer': 'Adagrad'}
# 0.522400 (0.006081) with: {'optimizer': 'SGD'}
# 0.605120 (0.004240) with: {'optimizer': 'RMSprop'}
# 0.833200 (0.004663) with: {'optimizer': 'Adagrad'}
# 0.690640 (0.008747) with: {'optimizer': 'Adadelta'}
# 0.639200 (0.003653) with: {'optimizer': 'Adam'}
# 0.791840 (0.004609) with: {'optimizer': 'Adamax'}
# 0.509160 (0.011387) with: {'optimizer': 'Nadam'}
# Out:
# Best: 0.833200 using {'optimizer': 'Adagrad'}
# 0.522400 (0.006081) with: {'optimizer': 'SGD'}
# 0.605120 (0.004240) with: {'optimizer': 'RMSprop'}
# 0.833200 (0.004663) with: {'optimizer': 'Adagrad'}
# 0.690640 (0.008747) with: {'optimizer': 'Adadelta'}
# 0.639200 (0.003653) with: {'optimizer': 'Adam'}
# 0.791840 (0.004609) with: {'optimizer': 'Adamax'}
# 0.509160 (0.011387) with: {'optimizer': 'Nadam'}

# %%
base_model = build_base_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_model_history = base_model.fit(X_train, y_train_tanh, batch_size=1, epochs=10)
# Out:
# Epoch 1/10
# 25000/25000 [==============================] - 27s 1ms/step - loss: 0.4703 - mean_absolute_error: 0.5341 - acc: 0.5502
# Epoch 2/10
# 25000/25000 [==============================] - 26s 1ms/step - loss: 0.3526 - mean_absolute_error: 0.4279 - acc: 0.6656
# Epoch 3/10
# 25000/25000 [==============================] - 26s 1ms/step - loss: 0.3251 - mean_absolute_error: 0.4003 - acc: 0.6922
# Epoch 4/10
# 25000/25000 [==============================] - 25s 1ms/step - loss: 0.3085 - mean_absolute_error: 0.3831 - acc: 0.7098
# Epoch 5/10
# 25000/25000 [==============================] - 26s 1ms/step - loss: 0.2976 - mean_absolute_error: 0.3711 - acc: 0.7217
# Epoch 6/10
# 25000/25000 [==============================] - 27s 1ms/step - loss: 0.2890 - mean_absolute_error: 0.3614 - acc: 0.7302
# Epoch 7/10
# 25000/25000 [==============================] - 25s 1ms/step - loss: 0.2823 - mean_absolute_error: 0.3539 - acc: 0.7376
# Epoch 8/10
# 25000/25000 [==============================] - 24s 976us/step - loss: 0.2767 - mean_absolute_error: 0.3475 - acc: 0.7435
# Epoch 9/10
# 25000/25000 [==============================] - 24s 962us/step - loss: 0.2720 - mean_absolute_error: 0.3420 - acc: 0.7488
# Epoch 10/10
# 25000/25000 [==============================] - 25s 994us/step - loss: 0.2678 - mean_absolute_error: 0.3370 - acc: 0.7523

# %%
# combined_model_history = combined_model.fit([X_train,y_train_agreement], y_train_original, batch_size=1, epochs=2)

# %%
base_model.trainable=False

# %%
build_combined_model()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_32 (InputLayer)           (None, 83)           0
# __________________________________________________________________________________________________
# input_31 (InputLayer)           (None, 3641)         0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               [(None, 1), (None, 1 0           input_32[0][0]
# __________________________________________________________________________________________________
# model_27 (Model)                (None, 1)            3642        input_31[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1)            0           lambda_2[0][0]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1)            0           lambda_2[0][1]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 1)            0           lambda_2[0][2]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1)            0           lambda_2[0][3]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1)            0           lambda_2[0][4]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1)            0           lambda_2[0][5]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1)            0           lambda_2[0][6]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 1)            0           lambda_2[0][7]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 1)            0           lambda_2[0][8]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 1)            0           lambda_2[0][9]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 1)            0           lambda_2[0][10]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 1)            0           lambda_2[0][11]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 1)            0           lambda_2[0][12]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 1)            0           lambda_2[0][13]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 1)            0           lambda_2[0][14]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 1)            0           lambda_2[0][15]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 1)            0           lambda_2[0][16]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 1)            0           lambda_2[0][17]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 1)            0           lambda_2[0][18]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 1)            0           lambda_2[0][19]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 1)            0           lambda_2[0][20]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 1)            0           lambda_2[0][21]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 1)            0           lambda_2[0][22]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 1)            0           lambda_2[0][23]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 1)            0           lambda_2[0][24]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 1)            0           lambda_2[0][25]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 1)            0           lambda_2[0][26]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 1)            0           lambda_2[0][27]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 1)            0           lambda_2[0][28]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 1)            0           lambda_2[0][29]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 1)            0           lambda_2[0][30]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 1)            0           lambda_2[0][31]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 1)            0           lambda_2[0][32]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 1)            0           lambda_2[0][33]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 1)            0           lambda_2[0][34]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 1)            0           lambda_2[0][35]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 1)            0           lambda_2[0][36]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 1)            0           lambda_2[0][37]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 1)            0           lambda_2[0][38]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 1)            0           lambda_2[0][39]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 1)            0           lambda_2[0][40]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 1)            0           lambda_2[0][41]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 1)            0           lambda_2[0][42]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_44 (Multiply)          (None, 1)            0           lambda_2[0][43]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_45 (Multiply)          (None, 1)            0           lambda_2[0][44]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_46 (Multiply)          (None, 1)            0           lambda_2[0][45]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_47 (Multiply)          (None, 1)            0           lambda_2[0][46]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_48 (Multiply)          (None, 1)            0           lambda_2[0][47]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_49 (Multiply)          (None, 1)            0           lambda_2[0][48]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_50 (Multiply)          (None, 1)            0           lambda_2[0][49]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_51 (Multiply)          (None, 1)            0           lambda_2[0][50]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_52 (Multiply)          (None, 1)            0           lambda_2[0][51]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_53 (Multiply)          (None, 1)            0           lambda_2[0][52]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_54 (Multiply)          (None, 1)            0           lambda_2[0][53]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_55 (Multiply)          (None, 1)            0           lambda_2[0][54]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_56 (Multiply)          (None, 1)            0           lambda_2[0][55]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_57 (Multiply)          (None, 1)            0           lambda_2[0][56]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_58 (Multiply)          (None, 1)            0           lambda_2[0][57]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_59 (Multiply)          (None, 1)            0           lambda_2[0][58]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_60 (Multiply)          (None, 1)            0           lambda_2[0][59]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_61 (Multiply)          (None, 1)            0           lambda_2[0][60]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_62 (Multiply)          (None, 1)            0           lambda_2[0][61]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_63 (Multiply)          (None, 1)            0           lambda_2[0][62]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_64 (Multiply)          (None, 1)            0           lambda_2[0][63]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_65 (Multiply)          (None, 1)            0           lambda_2[0][64]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_66 (Multiply)          (None, 1)            0           lambda_2[0][65]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_67 (Multiply)          (None, 1)            0           lambda_2[0][66]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_68 (Multiply)          (None, 1)            0           lambda_2[0][67]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_69 (Multiply)          (None, 1)            0           lambda_2[0][68]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_70 (Multiply)          (None, 1)            0           lambda_2[0][69]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_71 (Multiply)          (None, 1)            0           lambda_2[0][70]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_72 (Multiply)          (None, 1)            0           lambda_2[0][71]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_73 (Multiply)          (None, 1)            0           lambda_2[0][72]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_74 (Multiply)          (None, 1)            0           lambda_2[0][73]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_75 (Multiply)          (None, 1)            0           lambda_2[0][74]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_76 (Multiply)          (None, 1)            0           lambda_2[0][75]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_77 (Multiply)          (None, 1)            0           lambda_2[0][76]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_78 (Multiply)          (None, 1)            0           lambda_2[0][77]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_79 (Multiply)          (None, 1)            0           lambda_2[0][78]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_80 (Multiply)          (None, 1)            0           lambda_2[0][79]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_81 (Multiply)          (None, 1)            0           lambda_2[0][80]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_82 (Multiply)          (None, 1)            0           lambda_2[0][81]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# multiply_83 (Multiply)          (None, 1)            0           lambda_2[0][82]
#                                                                  model_27[2][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            1           multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            1           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            1           multiply_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            1           multiply_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            1           multiply_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            1           multiply_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            1           multiply_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            1           multiply_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            1           multiply_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            1           multiply_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            1           multiply_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            1           multiply_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1)            1           multiply_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1)            1           multiply_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            1           multiply_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            1           multiply_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1)            1           multiply_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1)            1           multiply_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1)            1           multiply_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1)            1           multiply_20[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1)            1           multiply_21[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1)            1           multiply_22[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1)            1           multiply_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1)            1           multiply_24[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 1)            1           multiply_25[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 1)            1           multiply_26[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            1           multiply_27[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 1)            1           multiply_28[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 1)            1           multiply_29[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 1)            1           multiply_30[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 1)            1           multiply_31[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 1)            1           multiply_32[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 1)            1           multiply_33[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 1)            1           multiply_34[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 1)            1           multiply_35[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 1)            1           multiply_36[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 1)            1           multiply_37[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 1)            1           multiply_38[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 1)            1           multiply_39[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 1)            1           multiply_40[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 1)            1           multiply_41[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 1)            1           multiply_42[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 1)            1           multiply_43[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 1)            1           multiply_44[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 1)            1           multiply_45[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 1)            1           multiply_46[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 1)            1           multiply_47[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 1)            1           multiply_48[0][0]
# __________________________________________________________________________________________________
# dense_49 (Dense)                (None, 1)            1           multiply_49[0][0]
# __________________________________________________________________________________________________
# dense_50 (Dense)                (None, 1)            1           multiply_50[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 1)            1           multiply_51[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 1)            1           multiply_52[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 1)            1           multiply_53[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 1)            1           multiply_54[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 1)            1           multiply_55[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 1)            1           multiply_56[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 1)            1           multiply_57[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 1)            1           multiply_58[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 1)            1           multiply_59[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 1)            1           multiply_60[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 1)            1           multiply_61[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 1)            1           multiply_62[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 1)            1           multiply_63[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 1)            1           multiply_64[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 1)            1           multiply_65[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 1)            1           multiply_66[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 1)            1           multiply_67[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 1)            1           multiply_68[0][0]
# __________________________________________________________________________________________________
# dense_69 (Dense)                (None, 1)            1           multiply_69[0][0]
# __________________________________________________________________________________________________
# dense_70 (Dense)                (None, 1)            1           multiply_70[0][0]
# __________________________________________________________________________________________________
# dense_71 (Dense)                (None, 1)            1           multiply_71[0][0]
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 1)            1           multiply_72[0][0]
# __________________________________________________________________________________________________
# dense_73 (Dense)                (None, 1)            1           multiply_73[0][0]
# __________________________________________________________________________________________________
# dense_74 (Dense)                (None, 1)            1           multiply_74[0][0]
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 1)            1           multiply_75[0][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 1)            1           multiply_76[0][0]
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 1)            1           multiply_77[0][0]
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 1)            1           multiply_78[0][0]
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 1)            1           multiply_79[0][0]
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 1)            1           multiply_80[0][0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 1)            1           multiply_81[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 1)            1           multiply_82[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 1)            1           multiply_83[0][0]
# __________________________________________________________________________________________________
# concatenate (Lambda)            (None, 83)           0           dense_1[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_4[0][0]
#                                                                  dense_5[0][0]
#                                                                  dense_6[0][0]
#                                                                  dense_7[0][0]
#                                                                  dense_8[0][0]
#                                                                  dense_9[0][0]
#                                                                  dense_10[0][0]
#                                                                  dense_11[0][0]
#                                                                  dense_12[0][0]
#                                                                  dense_13[0][0]
#                                                                  dense_14[0][0]
#                                                                  dense_15[0][0]
#                                                                  dense_16[0][0]
#                                                                  dense_17[0][0]
#                                                                  dense_18[0][0]
#                                                                  dense_19[0][0]
#                                                                  dense_20[0][0]
#                                                                  dense_21[0][0]
#                                                                  dense_22[0][0]
#                                                                  dense_23[0][0]
#                                                                  dense_24[0][0]
#                                                                  dense_25[0][0]
#                                                                  dense_26[0][0]
#                                                                  dense_27[0][0]
#                                                                  dense_28[0][0]
#                                                                  dense_29[0][0]
#                                                                  dense_30[0][0]
#                                                                  dense_31[0][0]
#                                                                  dense_32[0][0]
#                                                                  dense_33[0][0]
#                                                                  dense_34[0][0]
#                                                                  dense_35[0][0]
#                                                                  dense_36[0][0]
#                                                                  dense_37[0][0]
#                                                                  dense_38[0][0]
#                                                                  dense_39[0][0]
#                                                                  dense_40[0][0]
#                                                                  dense_41[0][0]
#                                                                  dense_42[0][0]
#                                                                  dense_43[0][0]
#                                                                  dense_44[0][0]
#                                                                  dense_45[0][0]
#                                                                  dense_46[0][0]
#                                                                  dense_47[0][0]
#                                                                  dense_48[0][0]
#                                                                  dense_49[0][0]
#                                                                  dense_50[0][0]
#                                                                  dense_51[0][0]
#                                                                  dense_52[0][0]
#                                                                  dense_53[0][0]
#                                                                  dense_54[0][0]
#                                                                  dense_55[0][0]
#                                                                  dense_56[0][0]
#                                                                  dense_57[0][0]
#                                                                  dense_58[0][0]
#                                                                  dense_59[0][0]
#                                                                  dense_60[0][0]
#                                                                  dense_61[0][0]
#                                                                  dense_62[0][0]
#                                                                  dense_63[0][0]
#                                                                  dense_64[0][0]
#                                                                  dense_65[0][0]
#                                                                  dense_66[0][0]
#                                                                  dense_67[0][0]
#                                                                  dense_68[0][0]
#                                                                  dense_69[0][0]
#                                                                  dense_70[0][0]
#                                                                  dense_71[0][0]
#                                                                  dense_72[0][0]
#                                                                  dense_73[0][0]
#                                                                  dense_74[0][0]
#                                                                  dense_75[0][0]
#                                                                  dense_76[0][0]
#                                                                  dense_77[0][0]
#                                                                  dense_78[0][0]
#                                                                  dense_79[0][0]
#                                                                  dense_80[0][0]
#                                                                  dense_81[0][0]
#                                                                  dense_82[0][0]
#                                                                  dense_83[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 1)            84          concatenate[0][0]
# ==================================================================================================
# Total params: 3,809
# Trainable params: 167
# Non-trainable params: 3,642
# __________________________________________________________________________________________________
# (<keras.engine.training.Model at 0x246bb44fc88>,
#  <keras.engine.training.Model at 0x246b4ddeda0>)

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

seed = 42
np.random.seed(seed)

input_shape=X_train.shape[1]
human_terms_len=len(word_list)
# create model
model = KerasClassifier(build_fn = build_combined_model, epochs=10, batch_size=1, verbose=0)

optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
param_grid = dict(optimizer=optimizer)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1)
grid_result = grid.fit([X_train, y_train_agreement], y_train_original)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-9b499235865b> in <module>()
#      13 param_grid = dict(optimizer=optimizer)
#      14 grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1)
# ---> 15 grid_result = grid.fit([X_train, y_train_agreement], y_train_original)
#      16
#      17 print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     613             refit_metric = 'score'
#     614
# --> 615         X, y, groups = indexable(X, y, groups)
#     616         n_splits = cv.get_n_splits(X, y, groups)
#     617         # Regenerate parameter iterable for each fit
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [2, 25000]

# %%
y_train_original.shape
# Out:
# (25000,)

# %%
y_train_agreement.shape
# Out:
# (25000, 83)

# %%
X_train.shape
# Out:
# (25000, 3641)
