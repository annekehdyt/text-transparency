# %%
from keras.layers import Input, Dense, TimeDistributed, Embedding
from keras.layers import Concatenate, Reshape, Lambda, Multiply, multiply, concatenate
from keras.models import Model
from keras import backend as K

import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

import tensorflow as tf
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# make first model

def build_base_model(input_shape):
    input_layer = Input(shape=(input_shape,))
    tanh_output = Dense(1, activation='tanh', name='tanh_output')(input_layer)
    
    model = Model(inputs=input_layer, outputs=tanh_output)
    model.summary()
    return model

# %%
# load data
# make sure that the first shape is the IMDB training data. 

def open_pickle(path):
    import pickle
    with open(path, 'rb') as f:
        X = pickle.load(f)
    return X

X_train_original = open_pickle('../../data/imdb/imdb_original_preprocessed_xtrain.pickle')
X_test_original = open_pickle('../../data/imdb/imdb_original_preprocessed_xtest.pickle')
y_train_original = open_pickle('../../data/imdb/imdb_original_preprocessed_ytrain.pickle')
y_test_original = open_pickle('../../data/imdb/imdb_original_preprocessed_ytest.pickle')

# %%
# Count vectorizer 

from sklearn.feature_extraction.text import CountVectorizer

token = r"(?u)\b[\w\'/]+\b"
cv = CountVectorizer(min_df = 100, token_pattern=token, lowercase=True, binary=True)
X_train = cv.fit_transform(X_train_original)
X_test = cv.transform(X_test_original)

# %%
def load_unigrams(path, X, y):
    word_list = []
    connotation = {}
    
    with open(path, 'r', encoding='utf8') as f:
        for line in f:
            word_list.append(line.strip())
            
    for word in word_list:
        pos_count = 0
        neg_count = 0
        for i, doc in enumerate(X):
            if word in doc.lower():
                if (y[i] == 1):
                    pos_count += 1
                else:
                    neg_count += 1
                    
        if pos_count > neg_count:
            connotation[word] = 1
        else:
            connotation[word] = 0
    
    return word_list, connotation

def generate_appearance(X_train_corpus, X_test_corpus, word_list, connotation):
    y_train_agreement = []
    for i in range(len(X_train_corpus)):
        doc_agreement = []
        for word in word_list:
            if word in X_train_corpus[i]:
                if connotation[word] == 1:
                    doc_agreement.append(1)
                else:
                    doc_agreement.append(-1)
            else:
                doc_agreement.append(0)
        y_train_agreement.append(doc_agreement)
        
    y_test_agreement = []
    for i in range(len(X_test_corpus)):
        doc_agreement = []
        for word in word_list:
            if word in X_test_corpus[i]:
                if connotation[word] == 1:
                    doc_agreement.append(1)
                else:
                    doc_agreement.append(-1)
            else:
                doc_agreement.append(0)
        y_test_agreement.append(doc_agreement)
        
    return np.array(y_train_agreement), np.array(y_test_agreement)

# 'imdb-unigrams.txt'

# %%
word_list, connotation = load_unigrams('./imdb-unigrams.txt', X_train_original, y_train_original)

# %%
y_train_agreement, y_test_agreement = generate_appearance(X_train_original, X_test_original, 
                                                          word_list, connotation)

# %%
def accuracy_reject(combined, X, y_agreement, y):
    
    # define model which get the input from combined model
    # output the value after relu
    human_terms_relu_model = Model(inputs=combined.input,
                                    outputs=combined.get_layer('concatenate').output)
    predict_relu = human_terms_relu_model.predict([X, y_agreement])
    accept_indices = np.where(np.sum(predict_relu, axis=1)!=0)
    accept_indices = accept_indices[0]
    total_reject = X.shape[0] - len(accept_indices)
    rejection_rate = total_reject/X.shape[0]

    test_eval = combined.evaluate([X[accept_indices], y_agreement[accept_indices]], y[accept_indices])
    
    return test_eval, rejection_rate

# %%
def layer_split(x):
    return tf.split(x,num_or_size_splits=human_terms_len,axis=1)

def layer_concat(x):
    return tf.concat(x, axis=1)

# %%
# build the combined model
# Combined model
human_terms_len = len(word_list)

base_model = build_base_model(X_train.shape[1])

combined_input_layer = Input(shape=(X_train.shape[1],))

# build the hard coded weight for human terms
ht_input_layer = Input(shape=(human_terms_len,))

# split = Lambda( lambda x: tf.split(x,num_or_size_splits=human_terms_len,axis=1))(ht_input_layer)
split = Lambda(layer_split)(ht_input_layer)


# get the document prediction
label_layer = base_model(combined_input_layer)

# stack the multiply layer
dense_layer = []
for i in range(human_terms_len):
    dense_layer.append(Dense(1, activation='relu',use_bias=False, kernel_initializer='ones')(Multiply()([split[i], label_layer])))

# concat all the result   
# concat = Lambda( lambda x: tf.concat(x, axis=1), name='concatenate')(dense_layer)
concat = Lambda(layer_concat, name='concatenate')(dense_layer)


# pass it to sigmoid layer
output_layer = Dense(1, activation='sigmoid')(concat)

combined_model = Model(inputs=[combined_input_layer, ht_input_layer], outputs=output_layer)
combined_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        (None, 3686)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3687
# =================================================================
# Total params: 3,687
# Trainable params: 3,687
# Non-trainable params: 0
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_21 (InputLayer)           (None, 83)           0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           (None, 3686)         0
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               [(None, 1), (None, 1 0           input_21[0][0]
# __________________________________________________________________________________________________
# model_25 (Model)                (None, 1)            3687        input_20[0][0]
# __________________________________________________________________________________________________
# multiply_416 (Multiply)         (None, 1)            0           lambda_6[0][0]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_417 (Multiply)         (None, 1)            0           lambda_6[0][1]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_418 (Multiply)         (None, 1)            0           lambda_6[0][2]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_419 (Multiply)         (None, 1)            0           lambda_6[0][3]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_420 (Multiply)         (None, 1)            0           lambda_6[0][4]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_421 (Multiply)         (None, 1)            0           lambda_6[0][5]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_422 (Multiply)         (None, 1)            0           lambda_6[0][6]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_423 (Multiply)         (None, 1)            0           lambda_6[0][7]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_424 (Multiply)         (None, 1)            0           lambda_6[0][8]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_425 (Multiply)         (None, 1)            0           lambda_6[0][9]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_426 (Multiply)         (None, 1)            0           lambda_6[0][10]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_427 (Multiply)         (None, 1)            0           lambda_6[0][11]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_428 (Multiply)         (None, 1)            0           lambda_6[0][12]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_429 (Multiply)         (None, 1)            0           lambda_6[0][13]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_430 (Multiply)         (None, 1)            0           lambda_6[0][14]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_431 (Multiply)         (None, 1)            0           lambda_6[0][15]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_432 (Multiply)         (None, 1)            0           lambda_6[0][16]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_433 (Multiply)         (None, 1)            0           lambda_6[0][17]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_434 (Multiply)         (None, 1)            0           lambda_6[0][18]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_435 (Multiply)         (None, 1)            0           lambda_6[0][19]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_436 (Multiply)         (None, 1)            0           lambda_6[0][20]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_437 (Multiply)         (None, 1)            0           lambda_6[0][21]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_438 (Multiply)         (None, 1)            0           lambda_6[0][22]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_439 (Multiply)         (None, 1)            0           lambda_6[0][23]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_440 (Multiply)         (None, 1)            0           lambda_6[0][24]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_441 (Multiply)         (None, 1)            0           lambda_6[0][25]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_442 (Multiply)         (None, 1)            0           lambda_6[0][26]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_443 (Multiply)         (None, 1)            0           lambda_6[0][27]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_444 (Multiply)         (None, 1)            0           lambda_6[0][28]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_445 (Multiply)         (None, 1)            0           lambda_6[0][29]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_446 (Multiply)         (None, 1)            0           lambda_6[0][30]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_447 (Multiply)         (None, 1)            0           lambda_6[0][31]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_448 (Multiply)         (None, 1)            0           lambda_6[0][32]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_449 (Multiply)         (None, 1)            0           lambda_6[0][33]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_450 (Multiply)         (None, 1)            0           lambda_6[0][34]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_451 (Multiply)         (None, 1)            0           lambda_6[0][35]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_452 (Multiply)         (None, 1)            0           lambda_6[0][36]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_453 (Multiply)         (None, 1)            0           lambda_6[0][37]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_454 (Multiply)         (None, 1)            0           lambda_6[0][38]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_455 (Multiply)         (None, 1)            0           lambda_6[0][39]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_456 (Multiply)         (None, 1)            0           lambda_6[0][40]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_457 (Multiply)         (None, 1)            0           lambda_6[0][41]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_458 (Multiply)         (None, 1)            0           lambda_6[0][42]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_459 (Multiply)         (None, 1)            0           lambda_6[0][43]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_460 (Multiply)         (None, 1)            0           lambda_6[0][44]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_461 (Multiply)         (None, 1)            0           lambda_6[0][45]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_462 (Multiply)         (None, 1)            0           lambda_6[0][46]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_463 (Multiply)         (None, 1)            0           lambda_6[0][47]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_464 (Multiply)         (None, 1)            0           lambda_6[0][48]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_465 (Multiply)         (None, 1)            0           lambda_6[0][49]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_466 (Multiply)         (None, 1)            0           lambda_6[0][50]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_467 (Multiply)         (None, 1)            0           lambda_6[0][51]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_468 (Multiply)         (None, 1)            0           lambda_6[0][52]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_469 (Multiply)         (None, 1)            0           lambda_6[0][53]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_470 (Multiply)         (None, 1)            0           lambda_6[0][54]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_471 (Multiply)         (None, 1)            0           lambda_6[0][55]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_472 (Multiply)         (None, 1)            0           lambda_6[0][56]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_473 (Multiply)         (None, 1)            0           lambda_6[0][57]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_474 (Multiply)         (None, 1)            0           lambda_6[0][58]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_475 (Multiply)         (None, 1)            0           lambda_6[0][59]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_476 (Multiply)         (None, 1)            0           lambda_6[0][60]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_477 (Multiply)         (None, 1)            0           lambda_6[0][61]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_478 (Multiply)         (None, 1)            0           lambda_6[0][62]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_479 (Multiply)         (None, 1)            0           lambda_6[0][63]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_480 (Multiply)         (None, 1)            0           lambda_6[0][64]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_481 (Multiply)         (None, 1)            0           lambda_6[0][65]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_482 (Multiply)         (None, 1)            0           lambda_6[0][66]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_483 (Multiply)         (None, 1)            0           lambda_6[0][67]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_484 (Multiply)         (None, 1)            0           lambda_6[0][68]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_485 (Multiply)         (None, 1)            0           lambda_6[0][69]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_486 (Multiply)         (None, 1)            0           lambda_6[0][70]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_487 (Multiply)         (None, 1)            0           lambda_6[0][71]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_488 (Multiply)         (None, 1)            0           lambda_6[0][72]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_489 (Multiply)         (None, 1)            0           lambda_6[0][73]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_490 (Multiply)         (None, 1)            0           lambda_6[0][74]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_491 (Multiply)         (None, 1)            0           lambda_6[0][75]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_492 (Multiply)         (None, 1)            0           lambda_6[0][76]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_493 (Multiply)         (None, 1)            0           lambda_6[0][77]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_494 (Multiply)         (None, 1)            0           lambda_6[0][78]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_495 (Multiply)         (None, 1)            0           lambda_6[0][79]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_496 (Multiply)         (None, 1)            0           lambda_6[0][80]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_497 (Multiply)         (None, 1)            0           lambda_6[0][81]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# multiply_498 (Multiply)         (None, 1)            0           lambda_6[0][82]
#                                                                  model_25[1][0]
# __________________________________________________________________________________________________
# dense_421 (Dense)               (None, 1)            1           multiply_416[0][0]
# __________________________________________________________________________________________________
# dense_422 (Dense)               (None, 1)            1           multiply_417[0][0]
# __________________________________________________________________________________________________
# dense_423 (Dense)               (None, 1)            1           multiply_418[0][0]
# __________________________________________________________________________________________________
# dense_424 (Dense)               (None, 1)            1           multiply_419[0][0]
# __________________________________________________________________________________________________
# dense_425 (Dense)               (None, 1)            1           multiply_420[0][0]
# __________________________________________________________________________________________________
# dense_426 (Dense)               (None, 1)            1           multiply_421[0][0]
# __________________________________________________________________________________________________
# dense_427 (Dense)               (None, 1)            1           multiply_422[0][0]
# __________________________________________________________________________________________________
# dense_428 (Dense)               (None, 1)            1           multiply_423[0][0]
# __________________________________________________________________________________________________
# dense_429 (Dense)               (None, 1)            1           multiply_424[0][0]
# __________________________________________________________________________________________________
# dense_430 (Dense)               (None, 1)            1           multiply_425[0][0]
# __________________________________________________________________________________________________
# dense_431 (Dense)               (None, 1)            1           multiply_426[0][0]
# __________________________________________________________________________________________________
# dense_432 (Dense)               (None, 1)            1           multiply_427[0][0]
# __________________________________________________________________________________________________
# dense_433 (Dense)               (None, 1)            1           multiply_428[0][0]
# __________________________________________________________________________________________________
# dense_434 (Dense)               (None, 1)            1           multiply_429[0][0]
# __________________________________________________________________________________________________
# dense_435 (Dense)               (None, 1)            1           multiply_430[0][0]
# __________________________________________________________________________________________________
# dense_436 (Dense)               (None, 1)            1           multiply_431[0][0]
# __________________________________________________________________________________________________
# dense_437 (Dense)               (None, 1)            1           multiply_432[0][0]
# __________________________________________________________________________________________________
# dense_438 (Dense)               (None, 1)            1           multiply_433[0][0]
# __________________________________________________________________________________________________
# dense_439 (Dense)               (None, 1)            1           multiply_434[0][0]
# __________________________________________________________________________________________________
# dense_440 (Dense)               (None, 1)            1           multiply_435[0][0]
# __________________________________________________________________________________________________
# dense_441 (Dense)               (None, 1)            1           multiply_436[0][0]
# __________________________________________________________________________________________________
# dense_442 (Dense)               (None, 1)            1           multiply_437[0][0]
# __________________________________________________________________________________________________
# dense_443 (Dense)               (None, 1)            1           multiply_438[0][0]
# __________________________________________________________________________________________________
# dense_444 (Dense)               (None, 1)            1           multiply_439[0][0]
# __________________________________________________________________________________________________
# dense_445 (Dense)               (None, 1)            1           multiply_440[0][0]
# __________________________________________________________________________________________________
# dense_446 (Dense)               (None, 1)            1           multiply_441[0][0]
# __________________________________________________________________________________________________
# dense_447 (Dense)               (None, 1)            1           multiply_442[0][0]
# __________________________________________________________________________________________________
# dense_448 (Dense)               (None, 1)            1           multiply_443[0][0]
# __________________________________________________________________________________________________
# dense_449 (Dense)               (None, 1)            1           multiply_444[0][0]
# __________________________________________________________________________________________________
# dense_450 (Dense)               (None, 1)            1           multiply_445[0][0]
# __________________________________________________________________________________________________
# dense_451 (Dense)               (None, 1)            1           multiply_446[0][0]
# __________________________________________________________________________________________________
# dense_452 (Dense)               (None, 1)            1           multiply_447[0][0]
# __________________________________________________________________________________________________
# dense_453 (Dense)               (None, 1)            1           multiply_448[0][0]
# __________________________________________________________________________________________________
# dense_454 (Dense)               (None, 1)            1           multiply_449[0][0]
# __________________________________________________________________________________________________
# dense_455 (Dense)               (None, 1)            1           multiply_450[0][0]
# __________________________________________________________________________________________________
# dense_456 (Dense)               (None, 1)            1           multiply_451[0][0]
# __________________________________________________________________________________________________
# dense_457 (Dense)               (None, 1)            1           multiply_452[0][0]
# __________________________________________________________________________________________________
# dense_458 (Dense)               (None, 1)            1           multiply_453[0][0]
# __________________________________________________________________________________________________
# dense_459 (Dense)               (None, 1)            1           multiply_454[0][0]
# __________________________________________________________________________________________________
# dense_460 (Dense)               (None, 1)            1           multiply_455[0][0]
# __________________________________________________________________________________________________
# dense_461 (Dense)               (None, 1)            1           multiply_456[0][0]
# __________________________________________________________________________________________________
# dense_462 (Dense)               (None, 1)            1           multiply_457[0][0]
# __________________________________________________________________________________________________
# dense_463 (Dense)               (None, 1)            1           multiply_458[0][0]
# __________________________________________________________________________________________________
# dense_464 (Dense)               (None, 1)            1           multiply_459[0][0]
# __________________________________________________________________________________________________
# dense_465 (Dense)               (None, 1)            1           multiply_460[0][0]
# __________________________________________________________________________________________________
# dense_466 (Dense)               (None, 1)            1           multiply_461[0][0]
# __________________________________________________________________________________________________
# dense_467 (Dense)               (None, 1)            1           multiply_462[0][0]
# __________________________________________________________________________________________________
# dense_468 (Dense)               (None, 1)            1           multiply_463[0][0]
# __________________________________________________________________________________________________
# dense_469 (Dense)               (None, 1)            1           multiply_464[0][0]
# __________________________________________________________________________________________________
# dense_470 (Dense)               (None, 1)            1           multiply_465[0][0]
# __________________________________________________________________________________________________
# dense_471 (Dense)               (None, 1)            1           multiply_466[0][0]
# __________________________________________________________________________________________________
# dense_472 (Dense)               (None, 1)            1           multiply_467[0][0]
# __________________________________________________________________________________________________
# dense_473 (Dense)               (None, 1)            1           multiply_468[0][0]
# __________________________________________________________________________________________________
# dense_474 (Dense)               (None, 1)            1           multiply_469[0][0]
# __________________________________________________________________________________________________
# dense_475 (Dense)               (None, 1)            1           multiply_470[0][0]
# __________________________________________________________________________________________________
# dense_476 (Dense)               (None, 1)            1           multiply_471[0][0]
# __________________________________________________________________________________________________
# dense_477 (Dense)               (None, 1)            1           multiply_472[0][0]
# __________________________________________________________________________________________________
# dense_478 (Dense)               (None, 1)            1           multiply_473[0][0]
# __________________________________________________________________________________________________
# dense_479 (Dense)               (None, 1)            1           multiply_474[0][0]
# __________________________________________________________________________________________________
# dense_480 (Dense)               (None, 1)            1           multiply_475[0][0]
# __________________________________________________________________________________________________
# dense_481 (Dense)               (None, 1)            1           multiply_476[0][0]
# __________________________________________________________________________________________________
# dense_482 (Dense)               (None, 1)            1           multiply_477[0][0]
# __________________________________________________________________________________________________
# dense_483 (Dense)               (None, 1)            1           multiply_478[0][0]
# __________________________________________________________________________________________________
# dense_484 (Dense)               (None, 1)            1           multiply_479[0][0]
# __________________________________________________________________________________________________
# dense_485 (Dense)               (None, 1)            1           multiply_480[0][0]
# __________________________________________________________________________________________________
# dense_486 (Dense)               (None, 1)            1           multiply_481[0][0]
# __________________________________________________________________________________________________
# dense_487 (Dense)               (None, 1)            1           multiply_482[0][0]
# __________________________________________________________________________________________________
# dense_488 (Dense)               (None, 1)            1           multiply_483[0][0]
# __________________________________________________________________________________________________
# dense_489 (Dense)               (None, 1)            1           multiply_484[0][0]
# __________________________________________________________________________________________________
# dense_490 (Dense)               (None, 1)            1           multiply_485[0][0]
# __________________________________________________________________________________________________
# dense_491 (Dense)               (None, 1)            1           multiply_486[0][0]
# __________________________________________________________________________________________________
# dense_492 (Dense)               (None, 1)            1           multiply_487[0][0]
# __________________________________________________________________________________________________
# dense_493 (Dense)               (None, 1)            1           multiply_488[0][0]
# __________________________________________________________________________________________________
# dense_494 (Dense)               (None, 1)            1           multiply_489[0][0]
# __________________________________________________________________________________________________
# dense_495 (Dense)               (None, 1)            1           multiply_490[0][0]
# __________________________________________________________________________________________________
# dense_496 (Dense)               (None, 1)            1           multiply_491[0][0]
# __________________________________________________________________________________________________
# dense_497 (Dense)               (None, 1)            1           multiply_492[0][0]
# __________________________________________________________________________________________________
# dense_498 (Dense)               (None, 1)            1           multiply_493[0][0]
# __________________________________________________________________________________________________
# dense_499 (Dense)               (None, 1)            1           multiply_494[0][0]
# __________________________________________________________________________________________________
# dense_500 (Dense)               (None, 1)            1           multiply_495[0][0]
# __________________________________________________________________________________________________
# dense_501 (Dense)               (None, 1)            1           multiply_496[0][0]
# __________________________________________________________________________________________________
# dense_502 (Dense)               (None, 1)            1           multiply_497[0][0]
# __________________________________________________________________________________________________
# dense_503 (Dense)               (None, 1)            1           multiply_498[0][0]
# __________________________________________________________________________________________________
# concatenate (Lambda)            (None, 83)           0           dense_421[0][0]
#                                                                  dense_422[0][0]
#                                                                  dense_423[0][0]
#                                                                  dense_424[0][0]
#                                                                  dense_425[0][0]
#                                                                  dense_426[0][0]
#                                                                  dense_427[0][0]
#                                                                  dense_428[0][0]
#                                                                  dense_429[0][0]
#                                                                  dense_430[0][0]
#                                                                  dense_431[0][0]
#                                                                  dense_432[0][0]
#                                                                  dense_433[0][0]
#                                                                  dense_434[0][0]
#                                                                  dense_435[0][0]
#                                                                  dense_436[0][0]
#                                                                  dense_437[0][0]
#                                                                  dense_438[0][0]
#                                                                  dense_439[0][0]
#                                                                  dense_440[0][0]
#                                                                  dense_441[0][0]
#                                                                  dense_442[0][0]
#                                                                  dense_443[0][0]
#                                                                  dense_444[0][0]
#                                                                  dense_445[0][0]
#                                                                  dense_446[0][0]
#                                                                  dense_447[0][0]
#                                                                  dense_448[0][0]
#                                                                  dense_449[0][0]
#                                                                  dense_450[0][0]
#                                                                  dense_451[0][0]
#                                                                  dense_452[0][0]
#                                                                  dense_453[0][0]
#                                                                  dense_454[0][0]
#                                                                  dense_455[0][0]
#                                                                  dense_456[0][0]
#                                                                  dense_457[0][0]
#                                                                  dense_458[0][0]
#                                                                  dense_459[0][0]
#                                                                  dense_460[0][0]
#                                                                  dense_461[0][0]
#                                                                  dense_462[0][0]
#                                                                  dense_463[0][0]
#                                                                  dense_464[0][0]
#                                                                  dense_465[0][0]
#                                                                  dense_466[0][0]
#                                                                  dense_467[0][0]
#                                                                  dense_468[0][0]
#                                                                  dense_469[0][0]
#                                                                  dense_470[0][0]
#                                                                  dense_471[0][0]
#                                                                  dense_472[0][0]
#                                                                  dense_473[0][0]
#                                                                  dense_474[0][0]
#                                                                  dense_475[0][0]
#                                                                  dense_476[0][0]
#                                                                  dense_477[0][0]
#                                                                  dense_478[0][0]
#                                                                  dense_479[0][0]
#                                                                  dense_480[0][0]
#                                                                  dense_481[0][0]
#                                                                  dense_482[0][0]
#                                                                  dense_483[0][0]
#                                                                  dense_484[0][0]
#                                                                  dense_485[0][0]
#                                                                  dense_486[0][0]
#                                                                  dense_487[0][0]
#                                                                  dense_488[0][0]
#                                                                  dense_489[0][0]
#                                                                  dense_490[0][0]
#                                                                  dense_491[0][0]
#                                                                  dense_492[0][0]
#                                                                  dense_493[0][0]
#                                                                  dense_494[0][0]
#                                                                  dense_495[0][0]
#                                                                  dense_496[0][0]
#                                                                  dense_497[0][0]
#                                                                  dense_498[0][0]
#                                                                  dense_499[0][0]
#                                                                  dense_500[0][0]
#                                                                  dense_501[0][0]
#                                                                  dense_502[0][0]
#                                                                  dense_503[0][0]
# __________________________________________________________________________________________________
# dense_504 (Dense)               (None, 1)            84          concatenate[0][0]
# ==================================================================================================
# Total params: 3,854
# Trainable params: 3,854
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
base_model.compile(loss='mse',
                  optimizer='adam',
                  metrics=['acc'])

base_model.trainable=True
combined_model.compile(loss='mse',
                      optimizer='adam',
                      metrics=['acc'])

# %%
y_train_tanh = y_train_original
y_train_tanh[y_train_tanh == 0] = -1

y_test_tanh = y_test_original
y_test_tanh[y_test_tanh == 0] = -1

# %%
y_train_agreement.shape
# Out:
# (25000, 83)

# %%
# base_model_history = base_model.fit(X_train[:16667], y_train_tanh[:16667], 
#                                     validation_data=(X_train[16667:], y_train_tanh[16667:]),
#                                     batch_size=1, epochs=1)

base_model_history = base_model.fit(X_test[:16667], y_test_tanh[:16667], 
                                    validation_data=(X_test[16667:], y_test_tanh[16667:]),
                                    batch_size=1, epochs=1)
# Out:
# Train on 16667 samples, validate on 8333 samples
# Epoch 1/1
# 16667/16667 [==============================] - 81s 5ms/step - loss: 0.4147 - acc: 0.6661 - val_loss: 0.3992 - val_acc: 0.7581

# %%
# combined_model_history = combined_model.fit([X_train[:16667],y_train_agreement[:16667]], y_train_original[:16667], 
#                                             validation_data=([X_train[16667:], y_train_agreement[16667:]], y_train_original[16667:]),
#                                             batch_size=1, epochs=1)

combined_model_history = combined_model.fit([X_test[:16667],y_test_agreement[:16667]], y_test_original[:16667], 
                                            validation_data=([X_test[16667:], y_test_agreement[16667:]], y_test_original[16667:]),
                                            batch_size=1, epochs=1)
# Out:
# Train on 16667 samples, validate on 8333 samples
# Epoch 1/1
# 16667/16667 [==============================] - 156s 9ms/step - loss: 0.7585 - acc: 0.3112 - val_loss: 0.7306 - val_acc: 0.3595

# %%
score = combined_model.evaluate([X_test, y_test_agreement], y_test_original)
score
# Out:
# 25000/25000 [==============================] - 4s 150us/step
# [0.6913259715270996, 0.37128]

# %%
accuracy_reject(combined_model, X_test, y_test_agreement, y_test_original)
# Out:
# 21915/21915 [==============================] - 3s 148us/step
# ([0.6486391934254059, 0.4235455167713759], 0.1234)

# %%
score = combined_model.evaluate([X_train, y_train_agreement], y_train_original)
score
# Out:
# 25000/25000 [==============================] - 4s 149us/step
# [0.7337338858413697, 0.35512]

# %%
accuracy_reject(combined_model, X_train, y_train_agreement, y_train_original)
# Out:
# 21867/21867 [==============================] - 3s 151us/step
# ([0.6967824189749722, 0.40599990853252804], 0.12532)

# %%
base_model.evaluate(X_train, y_tan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-e09ec7bb7ab2> in <module>()
# ----> 1 base_model.evaluate(X_train, y_tan)
#
# NameError: name 'y_tan' is not defined

# %%
base_model.evaluate(X_test, y_test_original)
# Out:
# 25000/25000 [==============================] - 2s 94us/step
# [1.0968767636108399, 0.2622]

# %% [markdown]
# ### Report

# %%
# Print report on the word transparency
index = [9, 19]
def report():
    for i in index:
        print()
        bm = base_model.predict(X_test[i])
        
        cm = combined_model.predict([X_test[i], 
                                np.reshape(y_test_agreement[i], (1,y_test_agreement.shape[1]))])
        
#         document_output = 'multiply'
#         document_predict = Model(inputs=combined_model.input,
#                                      outputs=combined_model.get_layer(document_output).output)
#         doc_output = document_predict.predict([np.reshape(data[i], (1,5)), 
#                                       ht_1_input[i], 
#                                       ht_2_input[i], 
#                                       ht_3_input[i], 
#                                       ht_4_input[i]])
        
        layer_name = 'concatenate'
        concat_after_relu = Model(inputs=combined_model.input,
                                     outputs=combined_model.get_layer(layer_name).output)
        concat_output = concat_after_relu.predict([X_test[i], 
                                np.reshape(y_test_agreement[i], (1,y_test_agreement.shape[1]))])
        
        print(X_test_original[i], '\n\n actual label : ', y_test_original[i], '\n predict from base model : ', bm.flatten(), '\n predict label : ', cm.flatten())
    
        for i,output in enumerate(concat_output.flatten()):
            if output != 0:
                print(word_list[i], output)

# %%
report()
# Out:
# hilarious, clean, light-hearted, and quote-worthy. what else can you ask for in a film? this is my all-time, number one favorite movie. ever since i was a little girl, i have dreamed of owning a blue van with flame and an observation bubble.the cliché character in ridiculous situation are what make this film such great fun. the wonderful comedic chemistry between stephen furst (harold) and andy tennant (melio) make up most of my favorite part of the movie. and who did not love the hopeless awkwardness of flynch? do not forget the airport antic of leon's crony, dressed up as hari krishna: dancing, chanting and playing the tambourine--unbeatable! the clue are genius, the location are classic, and the plot is timeless.a word to the wise, if you did not watch this film when you were little, it probably will not win a place in your heart today. but nevertheless give it a chance, you may find that "it does not matter what you say, it does not matter what you do, you have gotta play."
#
#  actual label :  1
#  predict from base model :  [0.99998087]
#  predict label :  [1.]
# favorite 3.3393843
# fun 2.948564
# great 2.5259075
# wonderful 2.8062205
#
# set just before the second world war, this is a touching and understated romantic story that is loosely based on a real event.it concern a german rocket scientist gerhart zucher (ulrich thomsen) working in britain in the advent of the second world war. fearing hitler may recall him to germany to assist him preparing for war, zucher and his slippery assistant heinz (eddie marsan) are evacuated by the british authority to a remote scottish island. they are given the task of building a rocket post box that will enable the islander to communicate with the mainland.mocked and bullied by the islander, they set up home with local girl catherine mackay (the stunning shauna macdonald), with whom thomsen begins an affair but complication arise when germany comes calling...the central romance between zucher and catherine is subtle and sincerely played and the supporting cast is a colourful bunch with an array of respected scottish character actor including gary lewis and clive russell.fine cinematography and a illiant central theme song sung in the local dialect round out this movie.intelligent but undemanding, it is good for a quiet evening in.
#
#  actual label :  1
#  predict from base model :  [0.99999523]
#  predict label :  [0.98618156]
# subtle 3.070125

# %%
score = combined_model.evaluate([X_test, y_test_agreement], y_test_original)
# Out:
# 25000/25000 [==============================] - 2s 88us/step

# %%
score
# Out:
# [0.16272140228033066, 0.78232]

# %% [markdown]
# ### Let's see the weight when the trainable is false

# %%
def build_combined_model():
    # build the combined model
    # Combined model
    human_terms_len = len(word_list)

    base_model = build_base_model(X_train.shape[1])

    combined_input_layer = Input(shape=(X_train.shape[1],))

    # build the hard coded weight for human terms
    ht_input_layer = Input(shape=(human_terms_len,))

    split = Lambda( lambda x: tf.split(x,num_or_size_splits=human_terms_len,axis=1))(ht_input_layer)

    # get the document prediction
    label_layer = base_model(combined_input_layer)

    # stack the multiply layer
    dense_layer = []
    for i in range(human_terms_len):
        dense_layer.append(Dense(1, activation='relu',use_bias=False, kernel_initializer='ones', trainable=True)(Multiply()([split[i], label_layer])))

    # concat all the result   
    concat = Lambda( lambda x: tf.concat(x, axis=1), name='concatenate')(dense_layer)

    # pass it to sigmoid layer
    output_layer = Dense(1, activation='sigmoid')(concat)

    combined_model = Model(inputs=[combined_input_layer, ht_input_layer], outputs=output_layer)
    combined_model.summary()
    
    return base_model, combined_model

# %%
false_base_model, false_combined_model = build_combined_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3686)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3687
# =================================================================
# Total params: 3,687
# Trainable params: 3,687
# Non-trainable params: 0
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 83)           0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 3686)         0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               [(None, 1), (None, 1 0           input_9[0][0]
# __________________________________________________________________________________________________
# model_5 (Model)                 (None, 1)            3687        input_8[0][0]
# __________________________________________________________________________________________________
# multiply_167 (Multiply)         (None, 1)            0           lambda_3[0][0]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_168 (Multiply)         (None, 1)            0           lambda_3[0][1]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_169 (Multiply)         (None, 1)            0           lambda_3[0][2]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_170 (Multiply)         (None, 1)            0           lambda_3[0][3]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_171 (Multiply)         (None, 1)            0           lambda_3[0][4]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_172 (Multiply)         (None, 1)            0           lambda_3[0][5]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_173 (Multiply)         (None, 1)            0           lambda_3[0][6]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_174 (Multiply)         (None, 1)            0           lambda_3[0][7]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_175 (Multiply)         (None, 1)            0           lambda_3[0][8]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_176 (Multiply)         (None, 1)            0           lambda_3[0][9]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_177 (Multiply)         (None, 1)            0           lambda_3[0][10]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_178 (Multiply)         (None, 1)            0           lambda_3[0][11]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_179 (Multiply)         (None, 1)            0           lambda_3[0][12]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_180 (Multiply)         (None, 1)            0           lambda_3[0][13]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_181 (Multiply)         (None, 1)            0           lambda_3[0][14]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_182 (Multiply)         (None, 1)            0           lambda_3[0][15]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_183 (Multiply)         (None, 1)            0           lambda_3[0][16]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_184 (Multiply)         (None, 1)            0           lambda_3[0][17]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_185 (Multiply)         (None, 1)            0           lambda_3[0][18]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_186 (Multiply)         (None, 1)            0           lambda_3[0][19]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_187 (Multiply)         (None, 1)            0           lambda_3[0][20]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_188 (Multiply)         (None, 1)            0           lambda_3[0][21]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_189 (Multiply)         (None, 1)            0           lambda_3[0][22]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_190 (Multiply)         (None, 1)            0           lambda_3[0][23]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_191 (Multiply)         (None, 1)            0           lambda_3[0][24]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_192 (Multiply)         (None, 1)            0           lambda_3[0][25]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_193 (Multiply)         (None, 1)            0           lambda_3[0][26]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_194 (Multiply)         (None, 1)            0           lambda_3[0][27]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_195 (Multiply)         (None, 1)            0           lambda_3[0][28]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_196 (Multiply)         (None, 1)            0           lambda_3[0][29]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_197 (Multiply)         (None, 1)            0           lambda_3[0][30]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_198 (Multiply)         (None, 1)            0           lambda_3[0][31]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_199 (Multiply)         (None, 1)            0           lambda_3[0][32]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_200 (Multiply)         (None, 1)            0           lambda_3[0][33]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_201 (Multiply)         (None, 1)            0           lambda_3[0][34]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_202 (Multiply)         (None, 1)            0           lambda_3[0][35]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_203 (Multiply)         (None, 1)            0           lambda_3[0][36]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_204 (Multiply)         (None, 1)            0           lambda_3[0][37]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_205 (Multiply)         (None, 1)            0           lambda_3[0][38]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_206 (Multiply)         (None, 1)            0           lambda_3[0][39]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_207 (Multiply)         (None, 1)            0           lambda_3[0][40]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_208 (Multiply)         (None, 1)            0           lambda_3[0][41]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_209 (Multiply)         (None, 1)            0           lambda_3[0][42]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_210 (Multiply)         (None, 1)            0           lambda_3[0][43]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_211 (Multiply)         (None, 1)            0           lambda_3[0][44]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_212 (Multiply)         (None, 1)            0           lambda_3[0][45]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_213 (Multiply)         (None, 1)            0           lambda_3[0][46]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_214 (Multiply)         (None, 1)            0           lambda_3[0][47]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_215 (Multiply)         (None, 1)            0           lambda_3[0][48]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_216 (Multiply)         (None, 1)            0           lambda_3[0][49]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_217 (Multiply)         (None, 1)            0           lambda_3[0][50]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_218 (Multiply)         (None, 1)            0           lambda_3[0][51]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_219 (Multiply)         (None, 1)            0           lambda_3[0][52]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_220 (Multiply)         (None, 1)            0           lambda_3[0][53]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_221 (Multiply)         (None, 1)            0           lambda_3[0][54]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_222 (Multiply)         (None, 1)            0           lambda_3[0][55]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_223 (Multiply)         (None, 1)            0           lambda_3[0][56]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_224 (Multiply)         (None, 1)            0           lambda_3[0][57]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_225 (Multiply)         (None, 1)            0           lambda_3[0][58]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_226 (Multiply)         (None, 1)            0           lambda_3[0][59]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_227 (Multiply)         (None, 1)            0           lambda_3[0][60]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_228 (Multiply)         (None, 1)            0           lambda_3[0][61]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_229 (Multiply)         (None, 1)            0           lambda_3[0][62]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_230 (Multiply)         (None, 1)            0           lambda_3[0][63]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_231 (Multiply)         (None, 1)            0           lambda_3[0][64]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_232 (Multiply)         (None, 1)            0           lambda_3[0][65]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_233 (Multiply)         (None, 1)            0           lambda_3[0][66]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_234 (Multiply)         (None, 1)            0           lambda_3[0][67]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_235 (Multiply)         (None, 1)            0           lambda_3[0][68]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_236 (Multiply)         (None, 1)            0           lambda_3[0][69]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_237 (Multiply)         (None, 1)            0           lambda_3[0][70]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_238 (Multiply)         (None, 1)            0           lambda_3[0][71]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_239 (Multiply)         (None, 1)            0           lambda_3[0][72]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_240 (Multiply)         (None, 1)            0           lambda_3[0][73]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_241 (Multiply)         (None, 1)            0           lambda_3[0][74]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_242 (Multiply)         (None, 1)            0           lambda_3[0][75]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_243 (Multiply)         (None, 1)            0           lambda_3[0][76]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_244 (Multiply)         (None, 1)            0           lambda_3[0][77]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_245 (Multiply)         (None, 1)            0           lambda_3[0][78]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_246 (Multiply)         (None, 1)            0           lambda_3[0][79]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_247 (Multiply)         (None, 1)            0           lambda_3[0][80]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_248 (Multiply)         (None, 1)            0           lambda_3[0][81]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# multiply_249 (Multiply)         (None, 1)            0           lambda_3[0][82]
#                                                                  model_5[1][0]
# __________________________________________________________________________________________________
# dense_169 (Dense)               (None, 1)            1           multiply_167[0][0]
# __________________________________________________________________________________________________
# dense_170 (Dense)               (None, 1)            1           multiply_168[0][0]
# __________________________________________________________________________________________________
# dense_171 (Dense)               (None, 1)            1           multiply_169[0][0]
# __________________________________________________________________________________________________
# dense_172 (Dense)               (None, 1)            1           multiply_170[0][0]
# __________________________________________________________________________________________________
# dense_173 (Dense)               (None, 1)            1           multiply_171[0][0]
# __________________________________________________________________________________________________
# dense_174 (Dense)               (None, 1)            1           multiply_172[0][0]
# __________________________________________________________________________________________________
# dense_175 (Dense)               (None, 1)            1           multiply_173[0][0]
# __________________________________________________________________________________________________
# dense_176 (Dense)               (None, 1)            1           multiply_174[0][0]
# __________________________________________________________________________________________________
# dense_177 (Dense)               (None, 1)            1           multiply_175[0][0]
# __________________________________________________________________________________________________
# dense_178 (Dense)               (None, 1)            1           multiply_176[0][0]
# __________________________________________________________________________________________________
# dense_179 (Dense)               (None, 1)            1           multiply_177[0][0]
# __________________________________________________________________________________________________
# dense_180 (Dense)               (None, 1)            1           multiply_178[0][0]
# __________________________________________________________________________________________________
# dense_181 (Dense)               (None, 1)            1           multiply_179[0][0]
# __________________________________________________________________________________________________
# dense_182 (Dense)               (None, 1)            1           multiply_180[0][0]
# __________________________________________________________________________________________________
# dense_183 (Dense)               (None, 1)            1           multiply_181[0][0]
# __________________________________________________________________________________________________
# dense_184 (Dense)               (None, 1)            1           multiply_182[0][0]
# __________________________________________________________________________________________________
# dense_185 (Dense)               (None, 1)            1           multiply_183[0][0]
# __________________________________________________________________________________________________
# dense_186 (Dense)               (None, 1)            1           multiply_184[0][0]
# __________________________________________________________________________________________________
# dense_187 (Dense)               (None, 1)            1           multiply_185[0][0]
# __________________________________________________________________________________________________
# dense_188 (Dense)               (None, 1)            1           multiply_186[0][0]
# __________________________________________________________________________________________________
# dense_189 (Dense)               (None, 1)            1           multiply_187[0][0]
# __________________________________________________________________________________________________
# dense_190 (Dense)               (None, 1)            1           multiply_188[0][0]
# __________________________________________________________________________________________________
# dense_191 (Dense)               (None, 1)            1           multiply_189[0][0]
# __________________________________________________________________________________________________
# dense_192 (Dense)               (None, 1)            1           multiply_190[0][0]
# __________________________________________________________________________________________________
# dense_193 (Dense)               (None, 1)            1           multiply_191[0][0]
# __________________________________________________________________________________________________
# dense_194 (Dense)               (None, 1)            1           multiply_192[0][0]
# __________________________________________________________________________________________________
# dense_195 (Dense)               (None, 1)            1           multiply_193[0][0]
# __________________________________________________________________________________________________
# dense_196 (Dense)               (None, 1)            1           multiply_194[0][0]
# __________________________________________________________________________________________________
# dense_197 (Dense)               (None, 1)            1           multiply_195[0][0]
# __________________________________________________________________________________________________
# dense_198 (Dense)               (None, 1)            1           multiply_196[0][0]
# __________________________________________________________________________________________________
# dense_199 (Dense)               (None, 1)            1           multiply_197[0][0]
# __________________________________________________________________________________________________
# dense_200 (Dense)               (None, 1)            1           multiply_198[0][0]
# __________________________________________________________________________________________________
# dense_201 (Dense)               (None, 1)            1           multiply_199[0][0]
# __________________________________________________________________________________________________
# dense_202 (Dense)               (None, 1)            1           multiply_200[0][0]
# __________________________________________________________________________________________________
# dense_203 (Dense)               (None, 1)            1           multiply_201[0][0]
# __________________________________________________________________________________________________
# dense_204 (Dense)               (None, 1)            1           multiply_202[0][0]
# __________________________________________________________________________________________________
# dense_205 (Dense)               (None, 1)            1           multiply_203[0][0]
# __________________________________________________________________________________________________
# dense_206 (Dense)               (None, 1)            1           multiply_204[0][0]
# __________________________________________________________________________________________________
# dense_207 (Dense)               (None, 1)            1           multiply_205[0][0]
# __________________________________________________________________________________________________
# dense_208 (Dense)               (None, 1)            1           multiply_206[0][0]
# __________________________________________________________________________________________________
# dense_209 (Dense)               (None, 1)            1           multiply_207[0][0]
# __________________________________________________________________________________________________
# dense_210 (Dense)               (None, 1)            1           multiply_208[0][0]
# __________________________________________________________________________________________________
# dense_211 (Dense)               (None, 1)            1           multiply_209[0][0]
# __________________________________________________________________________________________________
# dense_212 (Dense)               (None, 1)            1           multiply_210[0][0]
# __________________________________________________________________________________________________
# dense_213 (Dense)               (None, 1)            1           multiply_211[0][0]
# __________________________________________________________________________________________________
# dense_214 (Dense)               (None, 1)            1           multiply_212[0][0]
# __________________________________________________________________________________________________
# dense_215 (Dense)               (None, 1)            1           multiply_213[0][0]
# __________________________________________________________________________________________________
# dense_216 (Dense)               (None, 1)            1           multiply_214[0][0]
# __________________________________________________________________________________________________
# dense_217 (Dense)               (None, 1)            1           multiply_215[0][0]
# __________________________________________________________________________________________________
# dense_218 (Dense)               (None, 1)            1           multiply_216[0][0]
# __________________________________________________________________________________________________
# dense_219 (Dense)               (None, 1)            1           multiply_217[0][0]
# __________________________________________________________________________________________________
# dense_220 (Dense)               (None, 1)            1           multiply_218[0][0]
# __________________________________________________________________________________________________
# dense_221 (Dense)               (None, 1)            1           multiply_219[0][0]
# __________________________________________________________________________________________________
# dense_222 (Dense)               (None, 1)            1           multiply_220[0][0]
# __________________________________________________________________________________________________
# dense_223 (Dense)               (None, 1)            1           multiply_221[0][0]
# __________________________________________________________________________________________________
# dense_224 (Dense)               (None, 1)            1           multiply_222[0][0]
# __________________________________________________________________________________________________
# dense_225 (Dense)               (None, 1)            1           multiply_223[0][0]
# __________________________________________________________________________________________________
# dense_226 (Dense)               (None, 1)            1           multiply_224[0][0]
# __________________________________________________________________________________________________
# dense_227 (Dense)               (None, 1)            1           multiply_225[0][0]
# __________________________________________________________________________________________________
# dense_228 (Dense)               (None, 1)            1           multiply_226[0][0]
# __________________________________________________________________________________________________
# dense_229 (Dense)               (None, 1)            1           multiply_227[0][0]
# __________________________________________________________________________________________________
# dense_230 (Dense)               (None, 1)            1           multiply_228[0][0]
# __________________________________________________________________________________________________
# dense_231 (Dense)               (None, 1)            1           multiply_229[0][0]
# __________________________________________________________________________________________________
# dense_232 (Dense)               (None, 1)            1           multiply_230[0][0]
# __________________________________________________________________________________________________
# dense_233 (Dense)               (None, 1)            1           multiply_231[0][0]
# __________________________________________________________________________________________________
# dense_234 (Dense)               (None, 1)            1           multiply_232[0][0]
# __________________________________________________________________________________________________
# dense_235 (Dense)               (None, 1)            1           multiply_233[0][0]
# __________________________________________________________________________________________________
# dense_236 (Dense)               (None, 1)            1           multiply_234[0][0]
# __________________________________________________________________________________________________
# dense_237 (Dense)               (None, 1)            1           multiply_235[0][0]
# __________________________________________________________________________________________________
# dense_238 (Dense)               (None, 1)            1           multiply_236[0][0]
# __________________________________________________________________________________________________
# dense_239 (Dense)               (None, 1)            1           multiply_237[0][0]
# __________________________________________________________________________________________________
# dense_240 (Dense)               (None, 1)            1           multiply_238[0][0]
# __________________________________________________________________________________________________
# dense_241 (Dense)               (None, 1)            1           multiply_239[0][0]
# __________________________________________________________________________________________________
# dense_242 (Dense)               (None, 1)            1           multiply_240[0][0]
# __________________________________________________________________________________________________
# dense_243 (Dense)               (None, 1)            1           multiply_241[0][0]
# __________________________________________________________________________________________________
# dense_244 (Dense)               (None, 1)            1           multiply_242[0][0]
# __________________________________________________________________________________________________
# dense_245 (Dense)               (None, 1)            1           multiply_243[0][0]
# __________________________________________________________________________________________________
# dense_246 (Dense)               (None, 1)            1           multiply_244[0][0]
# __________________________________________________________________________________________________
# dense_247 (Dense)               (None, 1)            1           multiply_245[0][0]
# __________________________________________________________________________________________________
# dense_248 (Dense)               (None, 1)            1           multiply_246[0][0]
# __________________________________________________________________________________________________
# dense_249 (Dense)               (None, 1)            1           multiply_247[0][0]
# __________________________________________________________________________________________________
# dense_250 (Dense)               (None, 1)            1           multiply_248[0][0]
# __________________________________________________________________________________________________
# dense_251 (Dense)               (None, 1)            1           multiply_249[0][0]
# __________________________________________________________________________________________________
# concatenate (Lambda)            (None, 83)           0           dense_169[0][0]
#                                                                  dense_170[0][0]
#                                                                  dense_171[0][0]
#                                                                  dense_172[0][0]
#                                                                  dense_173[0][0]
#                                                                  dense_174[0][0]
#                                                                  dense_175[0][0]
#                                                                  dense_176[0][0]
#                                                                  dense_177[0][0]
#                                                                  dense_178[0][0]
#                                                                  dense_179[0][0]
#                                                                  dense_180[0][0]
#                                                                  dense_181[0][0]
#                                                                  dense_182[0][0]
#                                                                  dense_183[0][0]
#                                                                  dense_184[0][0]
#                                                                  dense_185[0][0]
#                                                                  dense_186[0][0]
#                                                                  dense_187[0][0]
#                                                                  dense_188[0][0]
#                                                                  dense_189[0][0]
#                                                                  dense_190[0][0]
#                                                                  dense_191[0][0]
#                                                                  dense_192[0][0]
#                                                                  dense_193[0][0]
#                                                                  dense_194[0][0]
#                                                                  dense_195[0][0]
#                                                                  dense_196[0][0]
#                                                                  dense_197[0][0]
#                                                                  dense_198[0][0]
#                                                                  dense_199[0][0]
#                                                                  dense_200[0][0]
#                                                                  dense_201[0][0]
#                                                                  dense_202[0][0]
#                                                                  dense_203[0][0]
#                                                                  dense_204[0][0]
#                                                                  dense_205[0][0]
#                                                                  dense_206[0][0]
#                                                                  dense_207[0][0]
#                                                                  dense_208[0][0]
#                                                                  dense_209[0][0]
#                                                                  dense_210[0][0]
#                                                                  dense_211[0][0]
#                                                                  dense_212[0][0]
#                                                                  dense_213[0][0]
#                                                                  dense_214[0][0]
#                                                                  dense_215[0][0]
#                                                                  dense_216[0][0]
#                                                                  dense_217[0][0]
#                                                                  dense_218[0][0]
#                                                                  dense_219[0][0]
#                                                                  dense_220[0][0]
#                                                                  dense_221[0][0]
#                                                                  dense_222[0][0]
#                                                                  dense_223[0][0]
#                                                                  dense_224[0][0]
#                                                                  dense_225[0][0]
#                                                                  dense_226[0][0]
#                                                                  dense_227[0][0]
#                                                                  dense_228[0][0]
#                                                                  dense_229[0][0]
#                                                                  dense_230[0][0]
#                                                                  dense_231[0][0]
#                                                                  dense_232[0][0]
#                                                                  dense_233[0][0]
#                                                                  dense_234[0][0]
#                                                                  dense_235[0][0]
#                                                                  dense_236[0][0]
#                                                                  dense_237[0][0]
#                                                                  dense_238[0][0]
#                                                                  dense_239[0][0]
#                                                                  dense_240[0][0]
#                                                                  dense_241[0][0]
#                                                                  dense_242[0][0]
#                                                                  dense_243[0][0]
#                                                                  dense_244[0][0]
#                                                                  dense_245[0][0]
#                                                                  dense_246[0][0]
#                                                                  dense_247[0][0]
#                                                                  dense_248[0][0]
#                                                                  dense_249[0][0]
#                                                                  dense_250[0][0]
#                                                                  dense_251[0][0]
# __________________________________________________________________________________________________
# dense_252 (Dense)               (None, 1)            84          concatenate[0][0]
# ==================================================================================================
# Total params: 3,854
# Trainable params: 3,854
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
false_base_model.compile(loss='mse',
                  optimizer='adam',
                  metrics=['acc'])

false_base_model.trainable=False

false_combined_model.compile(loss='mse',
                      optimizer='adam',
                      metrics=['acc'])

base_model_history_train_false = false_base_model.fit(X_train[:16667], y_train_tanh[:16667], 
                                    validation_data=(X_train[16667:], y_train_tanh[16667:]),
                                    batch_size=1, epochs=1)

combined_model_history_train_false = false_combined_model.fit([X_train[:16667],y_train_agreement[:16667]], y_train_original[:16667], batch_size=1, epochs=1)
# Out:
# c:\program files\python\lib\site-packages\keras\engine\training.py:479: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Train on 16667 samples, validate on 8333 samples
# Epoch 1/1
# 16667/16667 [==============================] - 32s 2ms/step - loss: 0.4160 - acc: 0.6702 - val_loss: 0.3847 - val_acc: 0.7571
# Epoch 1/1
# 16667/16667 [==============================] - 81s 5ms/step - loss: 0.7371 - acc: 0.3304

# %%
# Evaluate model

score = false_combined_model.evaluate([X_test, y_test_agreement], y_test_original)
score
# Out:
# 25000/25000 [==============================] - 2s 87us/step
# [0.13706384876012803, 0.81436]

# %%
accuracy_reject(false_combined_model, X_test, y_test_agreement, y_test_original)
# Out:
# 22026/22026 [==============================] - 2s 81us/step
# ([0.10435561584943832, 0.8663397802488687], 0.11896)

# %%
score = false_combined_model.evaluate([X_train, y_train_agreement], y_train_original)
score
# Out:
# 25000/25000 [==============================] - 2s 74us/step
# [0.6858638257026672, 0.35624]

# %%
accuracy_reject(false_combined_model, X_train, y_train_agreement, y_train_original)
# Out:
# 22061/22061 [==============================] - 2s 87us/step
# ([0.6450690616898749, 0.4036988350496261], 0.11756)
