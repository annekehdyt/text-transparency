# %%
import numpy as np

from human_terms_network import Human_Terms_Network
from dataset_load import *
from lr_baseline import LRBaseline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # IMDB

# %%
# open_pickle in dataset_load

X_train_original, X_test_original, y_train_original, y_test_original = load_imdb('../../data/imdb')

# %%
word_list, connotation = load_unigrams('./imdb-unigrams.txt', X_train_original, y_train_original)

# %%
y_train_agreement, y_test_agreement = generate_appearance(X_train_original, X_test_original, 
                                                          word_list, connotation)

# %%
imdb_baseline = LRBaseline(X_train_original, X_test_original, y_train_original, y_test_original, 
                           human_terms=word_list)

# %%
# (train, test)

print(imdb_baseline.baseline())
print(imdb_baseline.baseline(penalty='l1'))
print(imdb_baseline.human_terms_baseline())
print(imdb_baseline.human_terms_baseline(penalty='l2'))
# Out:
# (0.94412, 0.85576)
# (0.94112, 0.86268)
# (0.81476, 0.81072)
# (0.81476, 0.81072)

# %%
len(word_list)
# Out:
# 83

# %%
len(imdb_baseline.human_terms_cv.get_feature_names())
# Out:
# 83

# %%
len(imdb_baseline.baseline_cv.get_feature_names())
# Out:
# 3641

# %%
X_train = imdb_baseline.baseline_cv.transform(X_train_original)
X_test = imdb_baseline.baseline_cv.transform(X_test_original)
y_train = y_train_original
y_test = y_test_original

# %%
imdb_htm = Human_Terms_Network(input_shape=X_train.shape[1],
                               human_terms_shape=len(word_list),
                              domain='imdb')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3641)              0
# _________________________________________________________________
# tanh_output (Dense)          (None, 1)                 3642
# =================================================================
# Total params: 3,642
# Trainable params: 3,642
# Non-trainable params: 0
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 83)           0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 3641)         0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               [(None, 1), (None, 1 0           input_3[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 1)            3642        input_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1)            0           lambda_1[0][0]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1)            0           lambda_1[0][1]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 1)            0           lambda_1[0][2]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1)            0           lambda_1[0][3]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1)            0           lambda_1[0][4]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1)            0           lambda_1[0][5]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1)            0           lambda_1[0][6]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 1)            0           lambda_1[0][7]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 1)            0           lambda_1[0][8]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 1)            0           lambda_1[0][9]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 1)            0           lambda_1[0][10]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 1)            0           lambda_1[0][11]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 1)            0           lambda_1[0][12]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 1)            0           lambda_1[0][13]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 1)            0           lambda_1[0][14]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 1)            0           lambda_1[0][15]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 1)            0           lambda_1[0][16]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 1)            0           lambda_1[0][17]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 1)            0           lambda_1[0][18]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 1)            0           lambda_1[0][19]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 1)            0           lambda_1[0][20]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 1)            0           lambda_1[0][21]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 1)            0           lambda_1[0][22]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 1)            0           lambda_1[0][23]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 1)            0           lambda_1[0][24]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 1)            0           lambda_1[0][25]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 1)            0           lambda_1[0][26]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 1)            0           lambda_1[0][27]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 1)            0           lambda_1[0][28]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 1)            0           lambda_1[0][29]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 1)            0           lambda_1[0][30]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 1)            0           lambda_1[0][31]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 1)            0           lambda_1[0][32]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 1)            0           lambda_1[0][33]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 1)            0           lambda_1[0][34]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 1)            0           lambda_1[0][35]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 1)            0           lambda_1[0][36]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 1)            0           lambda_1[0][37]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 1)            0           lambda_1[0][38]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 1)            0           lambda_1[0][39]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 1)            0           lambda_1[0][40]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 1)            0           lambda_1[0][41]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 1)            0           lambda_1[0][42]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_44 (Multiply)          (None, 1)            0           lambda_1[0][43]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_45 (Multiply)          (None, 1)            0           lambda_1[0][44]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_46 (Multiply)          (None, 1)            0           lambda_1[0][45]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_47 (Multiply)          (None, 1)            0           lambda_1[0][46]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_48 (Multiply)          (None, 1)            0           lambda_1[0][47]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_49 (Multiply)          (None, 1)            0           lambda_1[0][48]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_50 (Multiply)          (None, 1)            0           lambda_1[0][49]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_51 (Multiply)          (None, 1)            0           lambda_1[0][50]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_52 (Multiply)          (None, 1)            0           lambda_1[0][51]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_53 (Multiply)          (None, 1)            0           lambda_1[0][52]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_54 (Multiply)          (None, 1)            0           lambda_1[0][53]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_55 (Multiply)          (None, 1)            0           lambda_1[0][54]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_56 (Multiply)          (None, 1)            0           lambda_1[0][55]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_57 (Multiply)          (None, 1)            0           lambda_1[0][56]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_58 (Multiply)          (None, 1)            0           lambda_1[0][57]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_59 (Multiply)          (None, 1)            0           lambda_1[0][58]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_60 (Multiply)          (None, 1)            0           lambda_1[0][59]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_61 (Multiply)          (None, 1)            0           lambda_1[0][60]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_62 (Multiply)          (None, 1)            0           lambda_1[0][61]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_63 (Multiply)          (None, 1)            0           lambda_1[0][62]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_64 (Multiply)          (None, 1)            0           lambda_1[0][63]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_65 (Multiply)          (None, 1)            0           lambda_1[0][64]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_66 (Multiply)          (None, 1)            0           lambda_1[0][65]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_67 (Multiply)          (None, 1)            0           lambda_1[0][66]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_68 (Multiply)          (None, 1)            0           lambda_1[0][67]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_69 (Multiply)          (None, 1)            0           lambda_1[0][68]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_70 (Multiply)          (None, 1)            0           lambda_1[0][69]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_71 (Multiply)          (None, 1)            0           lambda_1[0][70]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_72 (Multiply)          (None, 1)            0           lambda_1[0][71]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_73 (Multiply)          (None, 1)            0           lambda_1[0][72]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_74 (Multiply)          (None, 1)            0           lambda_1[0][73]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_75 (Multiply)          (None, 1)            0           lambda_1[0][74]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_76 (Multiply)          (None, 1)            0           lambda_1[0][75]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_77 (Multiply)          (None, 1)            0           lambda_1[0][76]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_78 (Multiply)          (None, 1)            0           lambda_1[0][77]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_79 (Multiply)          (None, 1)            0           lambda_1[0][78]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_80 (Multiply)          (None, 1)            0           lambda_1[0][79]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_81 (Multiply)          (None, 1)            0           lambda_1[0][80]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_82 (Multiply)          (None, 1)            0           lambda_1[0][81]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# multiply_83 (Multiply)          (None, 1)            0           lambda_1[0][82]
#                                                                  model_1[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            1           multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            1           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            1           multiply_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            1           multiply_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            1           multiply_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            1           multiply_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            1           multiply_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            1           multiply_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            1           multiply_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            1           multiply_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            1           multiply_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            1           multiply_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1)            1           multiply_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1)            1           multiply_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            1           multiply_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            1           multiply_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1)            1           multiply_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1)            1           multiply_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1)            1           multiply_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1)            1           multiply_20[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1)            1           multiply_21[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1)            1           multiply_22[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1)            1           multiply_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1)            1           multiply_24[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 1)            1           multiply_25[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 1)            1           multiply_26[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            1           multiply_27[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 1)            1           multiply_28[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 1)            1           multiply_29[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 1)            1           multiply_30[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 1)            1           multiply_31[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 1)            1           multiply_32[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 1)            1           multiply_33[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 1)            1           multiply_34[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 1)            1           multiply_35[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 1)            1           multiply_36[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 1)            1           multiply_37[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 1)            1           multiply_38[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 1)            1           multiply_39[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 1)            1           multiply_40[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 1)            1           multiply_41[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 1)            1           multiply_42[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 1)            1           multiply_43[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 1)            1           multiply_44[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 1)            1           multiply_45[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 1)            1           multiply_46[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 1)            1           multiply_47[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 1)            1           multiply_48[0][0]
# __________________________________________________________________________________________________
# dense_49 (Dense)                (None, 1)            1           multiply_49[0][0]
# __________________________________________________________________________________________________
# dense_50 (Dense)                (None, 1)            1           multiply_50[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 1)            1           multiply_51[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 1)            1           multiply_52[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 1)            1           multiply_53[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 1)            1           multiply_54[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 1)            1           multiply_55[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 1)            1           multiply_56[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 1)            1           multiply_57[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 1)            1           multiply_58[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 1)            1           multiply_59[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 1)            1           multiply_60[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 1)            1           multiply_61[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 1)            1           multiply_62[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 1)            1           multiply_63[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 1)            1           multiply_64[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 1)            1           multiply_65[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 1)            1           multiply_66[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 1)            1           multiply_67[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 1)            1           multiply_68[0][0]
# __________________________________________________________________________________________________
# dense_69 (Dense)                (None, 1)            1           multiply_69[0][0]
# __________________________________________________________________________________________________
# dense_70 (Dense)                (None, 1)            1           multiply_70[0][0]
# __________________________________________________________________________________________________
# dense_71 (Dense)                (None, 1)            1           multiply_71[0][0]
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 1)            1           multiply_72[0][0]
# __________________________________________________________________________________________________
# dense_73 (Dense)                (None, 1)            1           multiply_73[0][0]
# __________________________________________________________________________________________________
# dense_74 (Dense)                (None, 1)            1           multiply_74[0][0]
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 1)            1           multiply_75[0][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 1)            1           multiply_76[0][0]
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 1)            1           multiply_77[0][0]
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 1)            1           multiply_78[0][0]
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 1)            1           multiply_79[0][0]
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 1)            1           multiply_80[0][0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 1)            1           multiply_81[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 1)            1           multiply_82[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 1)            1           multiply_83[0][0]
# __________________________________________________________________________________________________
# concatenate (Lambda)            (None, 83)           0           dense_1[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_4[0][0]
#                                                                  dense_5[0][0]
#                                                                  dense_6[0][0]
#                                                                  dense_7[0][0]
#                                                                  dense_8[0][0]
#                                                                  dense_9[0][0]
#                                                                  dense_10[0][0]
#                                                                  dense_11[0][0]
#                                                                  dense_12[0][0]
#                                                                  dense_13[0][0]
#                                                                  dense_14[0][0]
#                                                                  dense_15[0][0]
#                                                                  dense_16[0][0]
#                                                                  dense_17[0][0]
#                                                                  dense_18[0][0]
#                                                                  dense_19[0][0]
#                                                                  dense_20[0][0]
#                                                                  dense_21[0][0]
#                                                                  dense_22[0][0]
#                                                                  dense_23[0][0]
#                                                                  dense_24[0][0]
#                                                                  dense_25[0][0]
#                                                                  dense_26[0][0]
#                                                                  dense_27[0][0]
#                                                                  dense_28[0][0]
#                                                                  dense_29[0][0]
#                                                                  dense_30[0][0]
#                                                                  dense_31[0][0]
#                                                                  dense_32[0][0]
#                                                                  dense_33[0][0]
#                                                                  dense_34[0][0]
#                                                                  dense_35[0][0]
#                                                                  dense_36[0][0]
#                                                                  dense_37[0][0]
#                                                                  dense_38[0][0]
#                                                                  dense_39[0][0]
#                                                                  dense_40[0][0]
#                                                                  dense_41[0][0]
#                                                                  dense_42[0][0]
#                                                                  dense_43[0][0]
#                                                                  dense_44[0][0]
#                                                                  dense_45[0][0]
#                                                                  dense_46[0][0]
#                                                                  dense_47[0][0]
#                                                                  dense_48[0][0]
#                                                                  dense_49[0][0]
#                                                                  dense_50[0][0]
#                                                                  dense_51[0][0]
#                                                                  dense_52[0][0]
#                                                                  dense_53[0][0]
#                                                                  dense_54[0][0]
#                                                                  dense_55[0][0]
#                                                                  dense_56[0][0]
#                                                                  dense_57[0][0]
#                                                                  dense_58[0][0]
#                                                                  dense_59[0][0]
#                                                                  dense_60[0][0]
#                                                                  dense_61[0][0]
#                                                                  dense_62[0][0]
#                                                                  dense_63[0][0]
#                                                                  dense_64[0][0]
#                                                                  dense_65[0][0]
#                                                                  dense_66[0][0]
#                                                                  dense_67[0][0]
#                                                                  dense_68[0][0]
#                                                                  dense_69[0][0]
#                                                                  dense_70[0][0]
#                                                                  dense_71[0][0]
#                                                                  dense_72[0][0]
#                                                                  dense_73[0][0]
#                                                                  dense_74[0][0]
#                                                                  dense_75[0][0]
#                                                                  dense_76[0][0]
#                                                                  dense_77[0][0]
#                                                                  dense_78[0][0]
#                                                                  dense_79[0][0]
#                                                                  dense_80[0][0]
#                                                                  dense_81[0][0]
#                                                                  dense_82[0][0]
#                                                                  dense_83[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 1)            84          concatenate[0][0]
# ==================================================================================================
# Total params: 3,809
# Trainable params: 3,809
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
imdb_htm.set_data(X_train, X_test, y_train_agreement, y_test_agreement, y_train, y_test)

# %%
imdb_htm.train(epochs=50)
# Out:
# Train on 16750 samples, validate on 8250 samples
# Epoch 1/50
# 16750/16750 [==============================] - 48s 3ms/step - loss: 0.2181 - mean_absolute_error: 0.2446 - acc: 0.8401 - val_loss: 0.3800 - val_mean_absolute_error: 0.3397 - val_acc: 0.7685
# Epoch 2/50
# 16750/16750 [==============================] - 49s 3ms/step - loss: 0.2145 - mean_absolute_error: 0.2431 - acc: 0.8417 - val_loss: 0.3793 - val_mean_absolute_error: 0.3396 - val_acc: 0.7686
# Epoch 3/50
# 16750/16750 [==============================] - 48s 3ms/step - loss: 0.2115 - mean_absolute_error: 0.2418 - acc: 0.8422 - val_loss: 0.3789 - val_mean_absolute_error: 0.3394 - val_acc: 0.7696
# Epoch 4/50
# 16750/16750 [==============================] - 48s 3ms/step - loss: 0.2089 - mean_absolute_error: 0.2406 - acc: 0.8426 - val_loss: 0.3787 - val_mean_absolute_error: 0.3393 - val_acc: 0.7698
# Epoch 5/50
# 16750/16750 [==============================] - 48s 3ms/step - loss: 0.2065 - mean_absolute_error: 0.2395 - acc: 0.8436 - val_loss: 0.3785 - val_mean_absolute_error: 0.3392 - val_acc: 0.7691
# Epoch 6/50
# 16750/16750 [==============================] - 48s 3ms/step - loss: 0.2044 - mean_absolute_error: 0.2384 - acc: 0.8442 - val_loss: 0.3783 - val_mean_absolute_error: 0.3391 - val_acc: 0.7701
# Epoch 7/50
# 16750/16750 [==============================] - 47s 3ms/step - loss: 0.2024 - mean_absolute_error: 0.2375 - acc: 0.8447 - val_loss: 0.3782 - val_mean_absolute_error: 0.3391 - val_acc: 0.7699
# Epoch 8/50
# 16750/16750 [==============================] - 47s 3ms/step - loss: 0.2007 - mean_absolute_error: 0.2366 - acc: 0.8444 - val_loss: 0.3782 - val_mean_absolute_error: 0.3390 - val_acc: 0.7698
# Epoch 9/50
# 16750/16750 [==============================] - 47s 3ms/step - loss: 0.1990 - mean_absolute_error: 0.2358 - acc: 0.8446 - val_loss: 0.3782 - val_mean_absolute_error: 0.3390 - val_acc: 0.7699
# Epoch 10/50
# 16750/16750 [==============================] - 46s 3ms/step - loss: 0.1975 - mean_absolute_error: 0.2350 - acc: 0.8450 - val_loss: 0.3782 - val_mean_absolute_error: 0.3389 - val_acc: 0.7707
# Epoch 11/50
# 16750/16750 [==============================] - 45s 3ms/step - loss: 0.1960 - mean_absolute_error: 0.2342 - acc: 0.8455 - val_loss: 0.3783 - val_mean_absolute_error: 0.3388 - val_acc: 0.7710
# Epoch 12/50
# 16750/16750 [==============================] - 45s 3ms/step - loss: 0.1947 - mean_absolute_error: 0.2335 - acc: 0.8460 - val_loss: 0.3784 - val_mean_absolute_error: 0.3388 - val_acc: 0.7714
# Epoch 13/50
# 16750/16750 [==============================] - 45s 3ms/step - loss: 0.1934 - mean_absolute_error: 0.2328 - acc: 0.8464 - val_loss: 0.3785 - val_mean_absolute_error: 0.3387 - val_acc: 0.7712
# Epoch 14/50
# 16750/16750 [==============================] - 45s 3ms/step - loss: 0.1922 - mean_absolute_error: 0.2321 - acc: 0.8467 - val_loss: 0.3786 - val_mean_absolute_error: 0.3387 - val_acc: 0.7712
# Epoch 15/50
# 16750/16750 [==============================] - 45s 3ms/step - loss: 0.1910 - mean_absolute_error: 0.2314 - acc: 0.8475 - val_loss: 0.3787 - val_mean_absolute_error: 0.3386 - val_acc: 0.7715
# Epoch 16/50
# 16750/16750 [==============================] - 45s 3ms/step - loss: 0.1899 - mean_absolute_error: 0.2308 - acc: 0.8478 - val_loss: 0.3788 - val_mean_absolute_error: 0.3386 - val_acc: 0.7714
# Epoch 17/50
# 16750/16750 [==============================] - 45s 3ms/step - loss: 0.1889 - mean_absolute_error: 0.2301 - acc: 0.8478 - val_loss: 0.3790 - val_mean_absolute_error: 0.3385 - val_acc: 0.7713
# Epoch 18/50
# 16750/16750 [==============================] - 45s 3ms/step - loss: 0.1879 - mean_absolute_error: 0.2295 - acc: 0.8481 - val_loss: 0.3791 - val_mean_absolute_error: 0.3384 - val_acc: 0.7713
# Epoch 19/50
# 16750/16750 [==============================] - 45s 3ms/step - loss: 0.1870 - mean_absolute_error: 0.2289 - acc: 0.8485 - val_loss: 0.3793 - val_mean_absolute_error: 0.3384 - val_acc: 0.7715
# Epoch 20/50
# 16750/16750 [==============================] - 41s 2ms/step - loss: 0.1860 - mean_absolute_error: 0.2283 - acc: 0.8492 - val_loss: 0.3794 - val_mean_absolute_error: 0.3383 - val_acc: 0.7716
# Epoch 21/50
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.1852 - mean_absolute_error: 0.2278 - acc: 0.8494 - val_loss: 0.3796 - val_mean_absolute_error: 0.3382 - val_acc: 0.7714
# Epoch 22/50
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.1843 - mean_absolute_error: 0.2272 - acc: 0.8499 - val_loss: 0.3798 - val_mean_absolute_error: 0.3381 - val_acc: 0.7718
# Epoch 23/50
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.1835 - mean_absolute_error: 0.2267 - acc: 0.8500 - val_loss: 0.3799 - val_mean_absolute_error: 0.3381 - val_acc: 0.7718
# Epoch 24/50
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.1827 - mean_absolute_error: 0.2261 - acc: 0.8504 - val_loss: 0.3801 - val_mean_absolute_error: 0.3380 - val_acc: 0.7714
# Epoch 25/50
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.1820 - mean_absolute_error: 0.2256 - acc: 0.8509 - val_loss: 0.3802 - val_mean_absolute_error: 0.3379 - val_acc: 0.7713
# Epoch 26/50
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.1812 - mean_absolute_error: 0.2251 - acc: 0.8515 - val_loss: 0.3804 - val_mean_absolute_error: 0.3378 - val_acc: 0.7710
# Epoch 27/50
# 16750/16750 [==============================] - 39s 2ms/step - loss: 0.1805 - mean_absolute_error: 0.2246 - acc: 0.8520 - val_loss: 0.3806 - val_mean_absolute_error: 0.3377 - val_acc: 0.7712
# Epoch 28/50
# 14617/16750 [=========================>....] - ETA: 3s - loss: 0.1791 - mean_absolute_error: 0.2237 - acc: 0.8521

# %%
imdb_htm.combined.evaluate([imdb_htm.X_test, imdb_htm.y_test_agreement], imdb_htm.y_test)
# Out:
# 25000/25000 [==============================] - 2s 80us/step
# [0.7377193391799927, 0.7177617022705078, 0.33124]

# %%
imdb_htm.X_test.shape
# Out:
# (25000, 3641)

# %%
imdb_htm.y_test_agreement.shape
# Out:
# (25000, 83)

# %%
imdb_htm.test()

# %% [markdown]
# # Amazon

# %%
path = r"..\..\data\reviews_Amazon_Instant_Video_5.json.gz"

X, y = extract_review_amazon(path, 'reviewText')

# discard the review with 3. [1,2] = 0, [4,5] = 0
neutral_indices = np.where(y_label == 3)[0]
y_label[y_label<3] = 0
y_label[y_label>3] = 1

X_discarded = np.delete(X,neutral_indices)
y_discarded = np.delete(y_label, neutral_indices)

from sklearn.model_selection import train_test_split

X_train_split, X_test_split, y_train_amazon, y_test_amazon = train_test_split(
    X_discarded, y_discarded)

X_train_corpus_update = update_corpus_contraction(X_train_split)
X_test_corpus_update = update_corpus_contraction(X_test_split)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b50e39d2b229> in <module>()
#       4
#       5 # discard the review with 3. [1,2] = 0, [4,5] = 0
# ----> 6 neutral_indices = np.where(y_label == 3)[0]
#       7 y_label[y_label<3] = 0
#       8 y_label[y_label>3] = 1
#
# NameError: name 'y_label' is not defined

# %%
# load human terms of Amazon Video

y_train_agreement_amazon, y_test_agreement_amazon = generate_appearance(X_train_corpus_update, X_test_corpus_update, 
                                                          word_list, connotation)

# %%
amazon_baseline = LRBaseline()

# run on 50 epochs
