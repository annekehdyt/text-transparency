# %%
import numpy as np
from numpy.random import seed
import tensorflow as tf

from tensorflow import set_random_seed
seed(42)
set_random_seed(42)

from keras.layers import Input, Dense, TimeDistributed, Embedding
from keras.layers import Concatenate, Reshape, Lambda, Multiply, multiply, concatenate
from keras.models import Model
from keras import backend as K

import matplotlib.pyplot as plt
from matplotlib import style

style.use('seaborn-whitegrid')

def open_pickle(path):
    import pickle
    with open(path, 'rb') as f:
        X = pickle.load(f)
    return X

def load_unigrams(path, X, y):
    word_list = []
    connotation = {}
    
    with open(path, 'r', encoding='utf8') as f:
        for line in f:
            word_list.append(line.strip())
            
    for word in word_list:
        pos_count = 0
        neg_count = 0
        for i, doc in enumerate(X):
            if word in doc.lower():
                
                if (y[i] == 1):
                    pos_count += 1
                else:
                    neg_count += 1
                    
        if pos_count > neg_count:
            connotation[word] = 1
        else:
            connotation[word] = 0
    
    return word_list, connotation

def generate_appearance(X_train_corpus, X_test_corpus, word_list, connotation):
    y_train_agreement = []
    for i in range(len(X_train_corpus)):
        doc_agreement = []
        for word in word_list:
            if word in X_train_corpus[i]:
                if connotation[word] == 1:
                    doc_agreement.append(1)
                else:
                    doc_agreement.append(-1)
            else:
                doc_agreement.append(0)
        y_train_agreement.append(doc_agreement)
        
    y_test_agreement = []
    for i in range(len(X_test_corpus)):
        doc_agreement = []
        for word in word_list:
            if word in X_test_corpus[i]:
                if connotation[word] == 1:
                    doc_agreement.append(1)
                else:
                    doc_agreement.append(-1)
            else:
                doc_agreement.append(0)
        y_test_agreement.append(doc_agreement)
        
    return np.array(y_train_agreement), np.array(y_test_agreement)

# 'imdb-unigrams.txt'

X_train_original = open_pickle('../../data/imdb/imdb_original_preprocessed_xtrain.pickle')
X_test_original = open_pickle('../../data/imdb/imdb_original_preprocessed_xtest.pickle')
y_train_original = open_pickle('../../data/imdb/imdb_original_preprocessed_ytrain.pickle')
y_test_original = open_pickle('../../data/imdb/imdb_original_preprocessed_ytest.pickle')

# Count vectorizer 

from sklearn.feature_extraction.text import CountVectorizer

token = r"(?u)\b[\w\'/]+\b"
cv = CountVectorizer(min_df = 100, token_pattern=token, lowercase=True, binary=True)
X_train = cv.fit_transform(X_train_original)
X_test = cv.transform(X_test_original)

word_list, connotation = load_unigrams('./imdb-unigrams.txt', X_train_original, y_train_original)

y_train_agreement, y_test_agreement = generate_appearance(X_train_original, X_test_original, 
                                                          word_list, connotation)


def history_plot(history, model_name):
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
        
    title = model_name + 'accuracy'
    plt.title(title)
    plt.xlabel('epoch')
    plt.legend(['tr_acc', 'val_acc'], loc='upper left')
    plt.show()
    plt.clf()

    plt.plot(history.history['loss'], 'm--')
    plt.plot(history.history['val_loss'], 'y--')

    title = model_name + 'loss'
    plt.title(title)
    plt.xlabel('epoch')
    plt.legend(['tr_loss', 'val_loss'], loc='upper left')
    plt.show()
    plt.clf()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Test the custom loss

# %%
# # https://stackoverflow.com/questions/48951109/keras-custom-binary-cross-entropy-loss-function-get-nan-as-output-for-loss

# def custom_cross_entropy(y_true, y_pred):
#     t_loss = K.max(y_pred,0)-y_pred * y_true + K.log(1+K.exp((-1)*K.abs(y_pred)))
#     return K.mean(t_loss)

# from keras.initializers import Constant, glorot_uniform

# input_layer = Input(shape=(X_train.shape[1],))
# tanh_output = Dense(1, activation='sigmoid', kernel_initializer=glorot_uniform(seed=42))(input_layer)
# model = Model(inputs=input_layer, outputs=tanh_output)

# model.compile(loss=custom_cross_entropy,
#              metrics=['acc'],
#              optimizer='adam')

# model.fit(X_train[:16667], y_train_original[:16667], 
#          validation_data=([X_train[16667:], y_train_original[16667:]]),
#          batch_size=1, epochs=1)

# %%
# model.evaluate(X_test, y_test_original)

# %%
# model.evaluate(X_train, y_train_original)

# %% [markdown]
# ### 1st model

# %%
from keras.initializers import Constant, glorot_uniform

input_layer = Input(shape=(X_train.shape[1],))
tanh_output = Dense(1, activation='sigmoid', kernel_initializer=glorot_uniform(seed=42))(input_layer)
model = Model(inputs=input_layer, outputs=tanh_output)

model.compile(loss='binary_crossentropy',
             metrics=['acc'],
             optimizer='adam')

base_history = model.fit(X_train[:16667], y_train_original[:16667], 
                 validation_data=([X_train[16667:], y_train_original[16667:]]),
                 batch_size=1, epochs=1)
# Out:
# Train on 16667 samples, validate on 8333 samples
# Epoch 1/1
# 16667/16667 [==============================] - 69s 4ms/step - loss: 0.3437 - acc: 0.8615 - val_loss: 0.3015 - val_acc: 0.8766

# %%
model.evaluate(X_test, y_test_original)
# Out:
# 25000/25000 [==============================] - 3s 105us/step
# [0.28974969831466674, 0.88192]

# %%
model.evaluate(X_train, y_train_original)
# Out:
# 25000/25000 [==============================] - 3s 106us/step
# [0.2486691696858406, 0.90652]

# %%
model.trainable=False

# %% [markdown]
# ### 2nd model

# %%
def layer_split(x):
    return tf.split(x,num_or_size_splits=human_terms_len,axis=1)

def layer_concat(x):
    return tf.concat(x, axis=1)

# build the combined model
# Combined model
human_terms_len = len(word_list)

# base_model = build_base_model(X_train.shape[1])

combined_input_layer = Input(shape=(X_train.shape[1],))

# build the hard coded weight for human terms
ht_input_layer = Input(shape=(human_terms_len,))

# split = Lambda( lambda x: tf.split(x,num_or_size_splits=human_terms_len,axis=1))(ht_input_layer)
split = Lambda(layer_split)(ht_input_layer)

# get the document prediction
label_layer = model(combined_input_layer)
tanh_norm = Lambda(lambda x: (x*2)-1)(label_layer)
# tanh_norm = Lambda(lambda x: tf.scalar_mul(2,x)-1)(label_layer)

# do normalize of bipolar sigmoid


# stack the multiply layer
dense_layer = []
for i in range(human_terms_len):
    dense_layer.append(Dense(1, activation='relu',use_)(Multiply()([split[i], tanh_norm])))

# concat all the result   
# concat = Lambda( lambda x: tf.concat(x, axis=1), name='concatenate')(dense_layer)
concat = Lambda(layer_concat, name='concatenate')(dense_layer)


# pass it to sigmoid layer
output_layer = Dense(1, activation='sigmoid')(concat)

combined_model = Model(inputs=[combined_input_layer, ht_input_layer], outputs=output_layer)
# combined_model.summary()


combined_model.compile(loss='binary_crossentropy',
                      optimizer='adam',
                      metrics=['acc'])

# y_train_tanh = y_train_original
# y_train_tanh[y_train_tanh == 0] = -1

# y_test_tanh = y_test_original
# y_test_tanh[y_test_tanh == 0] = -1

# base_model_history = base_model.fit(X_train[:16667], y_train_original[:16667], 
#                                     validation_data=(X_train[16667:], y_train_original[16667:]),
#                                     batch_size=1, epochs=1)

combined_model_history = combined_model.fit([X_train[:16667],y_train_agreement[:16667]], y_train_original[:16667], 
                                            validation_data=([X_train[16667:], y_train_agreement[16667:]], y_train_original[16667:]),
                                            batch_size=1, epochs=50)
# Out:
# Train on 16667 samples, validate on 8333 samples
# Epoch 1/50
# 16667/16667 [==============================] - 273s 16ms/step - loss: 0.3633 - acc: 0.8507 - val_loss: 0.3904 - val_acc: 0.8566
# Epoch 2/50
# 16667/16667 [==============================] - 213s 13ms/step - loss: 0.3049 - acc: 0.8722 - val_loss: 0.3922 - val_acc: 0.8540
# Epoch 3/50
# 16667/16667 [==============================] - 243s 15ms/step - loss: 0.2984 - acc: 0.8783 - val_loss: 0.3959 - val_acc: 0.8489
# Epoch 4/50
# 16667/16667 [==============================] - 237s 14ms/step - loss: 0.2961 - acc: 0.8790 - val_loss: 0.3938 - val_acc: 0.8580
# Epoch 5/50
# 16667/16667 [==============================] - 226s 14ms/step - loss: 0.2920 - acc: 0.8847 - val_loss: 0.3941 - val_acc: 0.8574
# Epoch 6/50
# 16667/16667 [==============================] - 232s 14ms/step - loss: 0.2907 - acc: 0.8829 - val_loss: 0.3956 - val_acc: 0.8548
# Epoch 7/50
# 16667/16667 [==============================] - 223s 13ms/step - loss: 0.2901 - acc: 0.8843 - val_loss: 0.3992 - val_acc: 0.8416
# Epoch 8/50
# 16667/16667 [==============================] - 263s 16ms/step - loss: 0.2882 - acc: 0.8868 - val_loss: 0.4027 - val_acc: 0.8465
# Epoch 9/50
# 16667/16667 [==============================] - 266s 16ms/step - loss: 0.2870 - acc: 0.8855 - val_loss: 0.3945 - val_acc: 0.8580
# Epoch 10/50
# 16667/16667 [==============================] - 266s 16ms/step - loss: 0.2863 - acc: 0.8878 - val_loss: 0.3969 - val_acc: 0.8603
# Epoch 11/50
# 16667/16667 [==============================] - 269s 16ms/step - loss: 0.2857 - acc: 0.8864 - val_loss: 0.4015 - val_acc: 0.8417
# Epoch 12/50
# 16667/16667 [==============================] - 273s 16ms/step - loss: 0.2851 - acc: 0.8872 - val_loss: 0.3976 - val_acc: 0.8606
# Epoch 13/50
# 16667/16667 [==============================] - 274s 16ms/step - loss: 0.2852 - acc: 0.8869 - val_loss: 0.3953 - val_acc: 0.8608
# Epoch 14/50
# 16667/16667 [==============================] - 265s 16ms/step - loss: 0.2845 - acc: 0.8876 - val_loss: 0.3985 - val_acc: 0.8432
# Epoch 15/50
# 16667/16667 [==============================] - 260s 16ms/step - loss: 0.2836 - acc: 0.8894 - val_loss: 0.4227 - val_acc: 0.8289
# Epoch 16/50
# 16667/16667 [==============================] - 260s 16ms/step - loss: 0.2844 - acc: 0.8877 - val_loss: 0.4005 - val_acc: 0.8432
# Epoch 17/50
# 16667/16667 [==============================] - 253s 15ms/step - loss: 0.2846 - acc: 0.8873 - val_loss: 0.3980 - val_acc: 0.8606
# Epoch 18/50
# 16667/16667 [==============================] - 256s 15ms/step - loss: 0.2829 - acc: 0.8894 - val_loss: 0.4007 - val_acc: 0.8574
# Epoch 19/50
# 16667/16667 [==============================] - 196s 12ms/step - loss: 0.2832 - acc: 0.8873 - val_loss: 0.4068 - val_acc: 0.8417
# Epoch 20/50
# 16667/16667 [==============================] - 189s 11ms/step - loss: 0.2828 - acc: 0.8899 - val_loss: 0.4042 - val_acc: 0.8553
# Epoch 21/50
# 16667/16667 [==============================] - 190s 11ms/step - loss: 0.2832 - acc: 0.8895 - val_loss: 0.4192 - val_acc: 0.8444
# Epoch 22/50
# 16667/16667 [==============================] - 187s 11ms/step - loss: 0.2831 - acc: 0.8871 - val_loss: 0.4055 - val_acc: 0.8428
# Epoch 23/50
# 16667/16667 [==============================] - 192s 12ms/step - loss: 0.2833 - acc: 0.8904 - val_loss: 0.4087 - val_acc: 0.8422
# Epoch 24/50
# 16667/16667 [==============================] - 202s 12ms/step - loss: 0.2841 - acc: 0.8853 - val_loss: 0.4162 - val_acc: 0.8357
# Epoch 25/50
# 16667/16667 [==============================] - 199s 12ms/step - loss: 0.2826 - acc: 0.8885 - val_loss: 0.4059 - val_acc: 0.8614
# Epoch 26/50
# 16667/16667 [==============================] - 171s 10ms/step - loss: 0.2841 - acc: 0.8877 - val_loss: 0.4092 - val_acc: 0.8562
# Epoch 27/50
# 16667/16667 [==============================] - 185s 11ms/step - loss: 0.2829 - acc: 0.8895 - val_loss: 0.4109 - val_acc: 0.8589
# Epoch 28/50
# 16667/16667 [==============================] - 182s 11ms/step - loss: 0.2833 - acc: 0.8876 - val_loss: 0.4227 - val_acc: 0.8355
# Epoch 29/50
# 16667/16667 [==============================] - 178s 11ms/step - loss: 0.2842 - acc: 0.8880 - val_loss: 0.4082 - val_acc: 0.8615
# Epoch 30/50
# 16667/16667 [==============================] - 184s 11ms/step - loss: 0.2827 - acc: 0.8878 - val_loss: 0.4128 - val_acc: 0.8445
# Epoch 31/50
# 16667/16667 [==============================] - 178s 11ms/step - loss: 0.2833 - acc: 0.8895 - val_loss: 0.4208 - val_acc: 0.8387
# Epoch 32/50
# 16667/16667 [==============================] - 188s 11ms/step - loss: 0.2831 - acc: 0.8900 - val_loss: 0.4086 - val_acc: 0.8614
# Epoch 33/50
# 16667/16667 [==============================] - 180s 11ms/step - loss: 0.2830 - acc: 0.8897 - val_loss: 0.4206 - val_acc: 0.8372
# Epoch 34/50
# 16667/16667 [==============================] - 176s 11ms/step - loss: 0.2830 - acc: 0.8882 - val_loss: 0.4090 - val_acc: 0.8614
# Epoch 35/50
# 16667/16667 [==============================] - 183s 11ms/step - loss: 0.2821 - acc: 0.8889 - val_loss: 0.4193 - val_acc: 0.8541
# Epoch 36/50
# 16667/16667 [==============================] - 182s 11ms/step - loss: 0.2829 - acc: 0.8880 - val_loss: 0.4130 - val_acc: 0.8595
# Epoch 37/50
# 16667/16667 [==============================] - 179s 11ms/step - loss: 0.2831 - acc: 0.8889 - val_loss: 0.4131 - val_acc: 0.8576
# Epoch 38/50
# 16667/16667 [==============================] - 181s 11ms/step - loss: 0.2828 - acc: 0.8900 - val_loss: 0.4192 - val_acc: 0.8426
# Epoch 39/50
# 16667/16667 [==============================] - 182s 11ms/step - loss: 0.2829 - acc: 0.8916 - val_loss: 0.4233 - val_acc: 0.8384
# Epoch 40/50
# 16667/16667 [==============================] - 177s 11ms/step - loss: 0.2835 - acc: 0.8879 - val_loss: 0.4116 - val_acc: 0.8602
# Epoch 41/50
# 16667/16667 [==============================] - 183s 11ms/step - loss: 0.2832 - acc: 0.8898 - val_loss: 0.4129 - val_acc: 0.8614
# Epoch 42/50
# 16667/16667 [==============================] - 179s 11ms/step - loss: 0.2831 - acc: 0.8892 - val_loss: 0.4160 - val_acc: 0.8423
# Epoch 43/50
# 16667/16667 [==============================] - 172s 10ms/step - loss: 0.2829 - acc: 0.8905 - val_loss: 0.4120 - val_acc: 0.8613
# Epoch 44/50
# 16667/16667 [==============================] - 180s 11ms/step - loss: 0.2823 - acc: 0.8904 - val_loss: 0.4189 - val_acc: 0.8422
# Epoch 45/50
# 16667/16667 [==============================] - 187s 11ms/step - loss: 0.2830 - acc: 0.8871 - val_loss: 0.4142 - val_acc: 0.8613
# Epoch 46/50
# 16667/16667 [==============================] - 183s 11ms/step - loss: 0.2832 - acc: 0.8901 - val_loss: 0.4125 - val_acc: 0.8586
# Epoch 47/50
# 16667/16667 [==============================] - 182s 11ms/step - loss: 0.2840 - acc: 0.8856 - val_loss: 0.4132 - val_acc: 0.8568
# Epoch 48/50
# 16667/16667 [==============================] - 177s 11ms/step - loss: 0.2826 - acc: 0.8873 - val_loss: 0.4115 - val_acc: 0.8618
# Epoch 49/50
# 16667/16667 [==============================] - 176s 11ms/step - loss: 0.2829 - acc: 0.8912 - val_loss: 0.4272 - val_acc: 0.8487
# Epoch 50/50
# 16667/16667 [==============================] - 180s 11ms/step - loss: 0.2823 - acc: 0.8863 - val_loss: 0.4138 - val_acc: 0.8567

# %%
combined_model.evaluate([X_test, y_test_agreement], y_test_original)
# Out:
# 25000/25000 [==============================] - 3s 101us/step
# [0.38588531238555906, 0.86104]

# %%
combined_model.evaluate([X_train, y_train_agreement], y_train_original)
# Out:
# 25000/25000 [==============================] - 2s 98us/step
# [0.3238055635499954, 0.87984]

# %%
history_plot(base_history,'RDclf')

# %%
history_plot(combined_model_history,'TTclf')

# %%
combined_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 3686)         0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 83)           0
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 1)            3687        input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               [(None, 1), (None, 1 0           input_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1)            0           model_1[1][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1)            0           lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1)            0           lambda_1[0][1]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 1)            0           lambda_1[0][2]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1)            0           lambda_1[0][3]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1)            0           lambda_1[0][4]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1)            0           lambda_1[0][5]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1)            0           lambda_1[0][6]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 1)            0           lambda_1[0][7]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 1)            0           lambda_1[0][8]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 1)            0           lambda_1[0][9]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 1)            0           lambda_1[0][10]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 1)            0           lambda_1[0][11]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 1)            0           lambda_1[0][12]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 1)            0           lambda_1[0][13]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 1)            0           lambda_1[0][14]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 1)            0           lambda_1[0][15]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 1)            0           lambda_1[0][16]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 1)            0           lambda_1[0][17]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 1)            0           lambda_1[0][18]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 1)            0           lambda_1[0][19]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 1)            0           lambda_1[0][20]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 1)            0           lambda_1[0][21]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 1)            0           lambda_1[0][22]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 1)            0           lambda_1[0][23]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 1)            0           lambda_1[0][24]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 1)            0           lambda_1[0][25]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 1)            0           lambda_1[0][26]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 1)            0           lambda_1[0][27]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 1)            0           lambda_1[0][28]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 1)            0           lambda_1[0][29]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 1)            0           lambda_1[0][30]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 1)            0           lambda_1[0][31]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 1)            0           lambda_1[0][32]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 1)            0           lambda_1[0][33]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 1)            0           lambda_1[0][34]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 1)            0           lambda_1[0][35]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 1)            0           lambda_1[0][36]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 1)            0           lambda_1[0][37]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 1)            0           lambda_1[0][38]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 1)            0           lambda_1[0][39]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 1)            0           lambda_1[0][40]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 1)            0           lambda_1[0][41]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 1)            0           lambda_1[0][42]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_44 (Multiply)          (None, 1)            0           lambda_1[0][43]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_45 (Multiply)          (None, 1)            0           lambda_1[0][44]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_46 (Multiply)          (None, 1)            0           lambda_1[0][45]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_47 (Multiply)          (None, 1)            0           lambda_1[0][46]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_48 (Multiply)          (None, 1)            0           lambda_1[0][47]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_49 (Multiply)          (None, 1)            0           lambda_1[0][48]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_50 (Multiply)          (None, 1)            0           lambda_1[0][49]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_51 (Multiply)          (None, 1)            0           lambda_1[0][50]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_52 (Multiply)          (None, 1)            0           lambda_1[0][51]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_53 (Multiply)          (None, 1)            0           lambda_1[0][52]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_54 (Multiply)          (None, 1)            0           lambda_1[0][53]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_55 (Multiply)          (None, 1)            0           lambda_1[0][54]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_56 (Multiply)          (None, 1)            0           lambda_1[0][55]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_57 (Multiply)          (None, 1)            0           lambda_1[0][56]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_58 (Multiply)          (None, 1)            0           lambda_1[0][57]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_59 (Multiply)          (None, 1)            0           lambda_1[0][58]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_60 (Multiply)          (None, 1)            0           lambda_1[0][59]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_61 (Multiply)          (None, 1)            0           lambda_1[0][60]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_62 (Multiply)          (None, 1)            0           lambda_1[0][61]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_63 (Multiply)          (None, 1)            0           lambda_1[0][62]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_64 (Multiply)          (None, 1)            0           lambda_1[0][63]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_65 (Multiply)          (None, 1)            0           lambda_1[0][64]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_66 (Multiply)          (None, 1)            0           lambda_1[0][65]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_67 (Multiply)          (None, 1)            0           lambda_1[0][66]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_68 (Multiply)          (None, 1)            0           lambda_1[0][67]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_69 (Multiply)          (None, 1)            0           lambda_1[0][68]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_70 (Multiply)          (None, 1)            0           lambda_1[0][69]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_71 (Multiply)          (None, 1)            0           lambda_1[0][70]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_72 (Multiply)          (None, 1)            0           lambda_1[0][71]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_73 (Multiply)          (None, 1)            0           lambda_1[0][72]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_74 (Multiply)          (None, 1)            0           lambda_1[0][73]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_75 (Multiply)          (None, 1)            0           lambda_1[0][74]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_76 (Multiply)          (None, 1)            0           lambda_1[0][75]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_77 (Multiply)          (None, 1)            0           lambda_1[0][76]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_78 (Multiply)          (None, 1)            0           lambda_1[0][77]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_79 (Multiply)          (None, 1)            0           lambda_1[0][78]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_80 (Multiply)          (None, 1)            0           lambda_1[0][79]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_81 (Multiply)          (None, 1)            0           lambda_1[0][80]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_82 (Multiply)          (None, 1)            0           lambda_1[0][81]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# multiply_83 (Multiply)          (None, 1)            0           lambda_1[0][82]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2           multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            2           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            2           multiply_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            2           multiply_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            2           multiply_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            2           multiply_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            2           multiply_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            2           multiply_8[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            2           multiply_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            2           multiply_10[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            2           multiply_11[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1)            2           multiply_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1)            2           multiply_13[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            2           multiply_14[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1)            2           multiply_15[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1)            2           multiply_16[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1)            2           multiply_17[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1)            2           multiply_18[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1)            2           multiply_19[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1)            2           multiply_20[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1)            2           multiply_21[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1)            2           multiply_22[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1)            2           multiply_23[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 1)            2           multiply_24[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 1)            2           multiply_25[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            2           multiply_26[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 1)            2           multiply_27[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 1)            2           multiply_28[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 1)            2           multiply_29[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 1)            2           multiply_30[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 1)            2           multiply_31[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 1)            2           multiply_32[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 1)            2           multiply_33[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 1)            2           multiply_34[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 1)            2           multiply_35[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 1)            2           multiply_36[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 1)            2           multiply_37[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 1)            2           multiply_38[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 1)            2           multiply_39[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 1)            2           multiply_40[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 1)            2           multiply_41[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 1)            2           multiply_42[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 1)            2           multiply_43[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 1)            2           multiply_44[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 1)            2           multiply_45[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 1)            2           multiply_46[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 1)            2           multiply_47[0][0]
# __________________________________________________________________________________________________
# dense_49 (Dense)                (None, 1)            2           multiply_48[0][0]
# __________________________________________________________________________________________________
# dense_50 (Dense)                (None, 1)            2           multiply_49[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 1)            2           multiply_50[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 1)            2           multiply_51[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 1)            2           multiply_52[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 1)            2           multiply_53[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 1)            2           multiply_54[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 1)            2           multiply_55[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 1)            2           multiply_56[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 1)            2           multiply_57[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 1)            2           multiply_58[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 1)            2           multiply_59[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 1)            2           multiply_60[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 1)            2           multiply_61[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 1)            2           multiply_62[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 1)            2           multiply_63[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 1)            2           multiply_64[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 1)            2           multiply_65[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 1)            2           multiply_66[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 1)            2           multiply_67[0][0]
# __________________________________________________________________________________________________
# dense_69 (Dense)                (None, 1)            2           multiply_68[0][0]
# __________________________________________________________________________________________________
# dense_70 (Dense)                (None, 1)            2           multiply_69[0][0]
# __________________________________________________________________________________________________
# dense_71 (Dense)                (None, 1)            2           multiply_70[0][0]
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 1)            2           multiply_71[0][0]
# __________________________________________________________________________________________________
# dense_73 (Dense)                (None, 1)            2           multiply_72[0][0]
# __________________________________________________________________________________________________
# dense_74 (Dense)                (None, 1)            2           multiply_73[0][0]
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 1)            2           multiply_74[0][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 1)            2           multiply_75[0][0]
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 1)            2           multiply_76[0][0]
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 1)            2           multiply_77[0][0]
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 1)            2           multiply_78[0][0]
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 1)            2           multiply_79[0][0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 1)            2           multiply_80[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 1)            2           multiply_81[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 1)            2           multiply_82[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 1)            2           multiply_83[0][0]
# __________________________________________________________________________________________________
# concatenate (Lambda)            (None, 83)           0           dense_2[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_4[0][0]
#                                                                  dense_5[0][0]
#                                                                  dense_6[0][0]
#                                                                  dense_7[0][0]
#                                                                  dense_8[0][0]
#                                                                  dense_9[0][0]
#                                                                  dense_10[0][0]
#                                                                  dense_11[0][0]
#                                                                  dense_12[0][0]
#                                                                  dense_13[0][0]
#                                                                  dense_14[0][0]
#                                                                  dense_15[0][0]
#                                                                  dense_16[0][0]
#                                                                  dense_17[0][0]
#                                                                  dense_18[0][0]
#                                                                  dense_19[0][0]
#                                                                  dense_20[0][0]
#                                                                  dense_21[0][0]
#                                                                  dense_22[0][0]
#                                                                  dense_23[0][0]
#                                                                  dense_24[0][0]
#                                                                  dense_25[0][0]
#                                                                  dense_26[0][0]
#                                                                  dense_27[0][0]
#                                                                  dense_28[0][0]
#                                                                  dense_29[0][0]
#                                                                  dense_30[0][0]
#                                                                  dense_31[0][0]
#                                                                  dense_32[0][0]
#                                                                  dense_33[0][0]
#                                                                  dense_34[0][0]
#                                                                  dense_35[0][0]
#                                                                  dense_36[0][0]
#                                                                  dense_37[0][0]
#                                                                  dense_38[0][0]
#                                                                  dense_39[0][0]
#                                                                  dense_40[0][0]
#                                                                  dense_41[0][0]
#                                                                  dense_42[0][0]
#                                                                  dense_43[0][0]
#                                                                  dense_44[0][0]
#                                                                  dense_45[0][0]
#                                                                  dense_46[0][0]
#                                                                  dense_47[0][0]
#                                                                  dense_48[0][0]
#                                                                  dense_49[0][0]
#                                                                  dense_50[0][0]
#                                                                  dense_51[0][0]
#                                                                  dense_52[0][0]
#                                                                  dense_53[0][0]
#                                                                  dense_54[0][0]
#                                                                  dense_55[0][0]
#                                                                  dense_56[0][0]
#                                                                  dense_57[0][0]
#                                                                  dense_58[0][0]
#                                                                  dense_59[0][0]
#                                                                  dense_60[0][0]
#                                                                  dense_61[0][0]
#                                                                  dense_62[0][0]
#                                                                  dense_63[0][0]
#                                                                  dense_64[0][0]
#                                                                  dense_65[0][0]
#                                                                  dense_66[0][0]
#                                                                  dense_67[0][0]
#                                                                  dense_68[0][0]
#                                                                  dense_69[0][0]
#                                                                  dense_70[0][0]
#                                                                  dense_71[0][0]
#                                                                  dense_72[0][0]
#                                                                  dense_73[0][0]
#                                                                  dense_74[0][0]
#                                                                  dense_75[0][0]
#                                                                  dense_76[0][0]
#                                                                  dense_77[0][0]
#                                                                  dense_78[0][0]
#                                                                  dense_79[0][0]
#                                                                  dense_80[0][0]
#                                                                  dense_81[0][0]
#                                                                  dense_82[0][0]
#                                                                  dense_83[0][0]
#                                                                  dense_84[0][0]
# __________________________________________________________________________________________________
# dense_85 (Dense)                (None, 1)            84          concatenate[0][0]
# ==================================================================================================
# Total params: 3,937
# Trainable params: 250
# Non-trainable params: 3,687
# __________________________________________________________________________________________________

# %%
combined_model_history.history['loss']
# Out:
# [0.36333011728319387,
#  0.3049280625399847,
#  0.298363236463383,
#  0.29611853759818135,
#  0.2920176735437995,
#  0.29071868484789026,
#  0.29014621885493735,
#  0.28822951864796176,
#  0.2869605918927627,
#  0.28626183745883016,
#  0.2856819012708601,
#  0.2851354764244891,
#  0.28518618942728047,
#  0.28445241824574025,
#  0.283570197392678,
#  0.2844156932403229,
#  0.2845792040932727,
#  0.28291910842012075,
#  0.28318385905145693,
#  0.28282390131401663,
#  0.283184909755689,
#  0.2831419459785107,
#  0.2833438048686581,
#  0.28411843252239705,
#  0.2825650737314733,
#  0.28408821495566355,
#  0.2828831970915774,
#  0.2832868714559784,
#  0.284160943536324,
#  0.2827270904543542,
#  0.2832774291414822,
#  0.2831148857189504,
#  0.2830131246987775,
#  0.2830256447480512,
#  0.2821328508412608,
#  0.28288606818939227,
#  0.28306116177970697,
#  0.28279248842490423,
#  0.282858510931623,
#  0.2834509867633602,
#  0.2831653387899703,
#  0.2830803759203618,
#  0.28293121363041185,
#  0.28230562799886266,
#  0.2830312953056059,
#  0.28321948337691294,
#  0.2839544757152468,
#  0.28263612341916666,
#  0.2828722621781155,
#  0.2823172353219757]
